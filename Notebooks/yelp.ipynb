# %%
# %pip install yelpapi
# %pip install requests
# Out:
# Requirement already satisfied: yelpapi in c:\python39\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\yporq\appdata\roaming\python\python39\site-packages (from yelpapi) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# Requirement already satisfied: requests in c:\users\yporq\appdata\roaming\python\python39\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)

# %% [markdown]
# client_id, api_key

# %%
from yelpapi import YelpAPI
import pandas as pd
import requests
yelp_api = YelpAPI(api_key)

# %%
#distritos = ['Centro', 'Arganzuela', 'Retiro', 'Salamanca', 'Chamartín', 'Tetuán', 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca', 'Latina', 'Carabanchel', 'Usera', 'Puente de Vallecas', 'Moratalaz', 'Ciudad Lineal', 'Hortaleza', 'Villaverde', 'Villa de Vallecas', 'Vicálvaro', 'San Blas-Canillejas', 'Barajas']
"""
Aída - 1,2,3 - 'Centro', 'Arganzuela', 'Retiro'
Carlos - 4,5,6 - 'Salamanca', 'Chamartín', 'Tetuán'
Marina - 7,8,9 - 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca'
Fernando - 10,11,12 - 'Latina', 'Carabanchel', 'Usera'
Víctor - 13,14,15 - 'Puente de Vallecas', 'Moratalaz', 'Ciudad Lineal'
Richi - 16,17,18 -  'Hortaleza', 'Villaverde', 'Villa de Vallecas'
Álvaro - 19,20,21 - 'Vicálvaro', 'San Blas-Canillejas', 'Barajas'

"""
# Out:
# "\nAída - 1,2,3 - 'Centro', 'Arganzuela', 'Retiro'\nCarlos - 4,5,6 - 'Salamanca', 'Chamartín', 'Tetuán'\nMarina - 7,8,9 - 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca'\nFernando - 10,11,12 - 'Latina', 'Carabanchel', 'Usera'\nVíctor - 13,14,15 - 'Puente de Vallecas', 'Moratalaz', 'Ciudad Lineal'\nRichi - 16,17,18 -  'Hortaleza', 'Villaverde', 'Villa de Vallecas'\nÁlvaro - 19,20,21 - 'Vicálvaro', 'San Blas-Canillejas', 'Barajas'\n\n"

# %%
distritos = [
    {"district": "Centro", "latitude": 40.415363, "longitude": -3.707398},
    {"district": "Arganzuela", "latitude": 40.398068, "longitude": -3.693734},
    {"district": "Retiro", "latitude": 40.411894, "longitude": -3.676574},
    {"district": "Salamanca", "latitude": 40.427919, "longitude": -3.680877},
    {"district": "Chamartín", "latitude": 40.462428, "longitude": -3.676057},
    {"district": "Tetuán", "latitude": 40.466676, "longitude": -3.698984},
    {"district": "Chamberí", "latitude": 40.436247, "longitude": -3.703830},
    {"district": "Fuencarral-El Pardo", "latitude": 40.515923, "longitude": -3.785586},
    {"district": "Moncloa-Aravaca", "latitude": 40.439883, "longitude": -3.744509},
    {"district": "Latina", "latitude": 40.388981, "longitude": -3.753525},
    {"district": "Carabanchel", "latitude": 40.377818, "longitude": -3.751209},
    {"district": "Usera", "latitude": 40.383553, "longitude": -3.706070},
    {"district": "Puente de Vallecas", "latitude": 40.389491, "longitude": -3.669062},
    {"district": "Moratalaz", "latitude": 40.407251, "longitude": -3.644992},
    {"district": "Ciudad Lineal", "latitude": 40.448431, "longitude": -3.650495},
    {"district": "Hortaleza", "latitude": 40.474457, "longitude": -3.640892},
    {"district": "Villaverde", "latitude": 40.345610, "longitude": -3.695956},
    {"district": "Villa de Vallecas", "latitude": 40.367040, "longitude": -3.612046},
    {"district": "Vicálvaro", "latitude": 40.396584, "longitude": -3.576622},
    {"district": "San Blas-Canillejas", "latitude": 40.428918, "longitude": -3.609064},
    {"district": "Barajas", "latitude": 40.477628, "longitude": -3.579394}
]

# %%
distritos[0]["district"]
# Out:
# 'Centro'

# %%
url = 'https://api.yelp.com/v3/businesses/search'
params = {    
        
        'categories': 'restaurants',
        "radius": 5000,
        'limit': 2  # Number of results to retrieve (max is 50)
    }
headers = {
    'Authorization': 'Bearer ' + api_key
}
res = []
for dis in distritos[3:6]:  
    params = {    
        "latitude": dis["latitude"],
        "longitude": dis["longitude"]        
    }
    
    # Send GET request to the API
    response = requests.get(url, headers=headers, params=params)
    if response.headers.get("Content-Type") == "application/json":
        try:
            # Parse the JSON response
            data = response.json()
           
            # Extract and process restaurants
            restaurants = data['businesses']           
            
            for restaurant in restaurants:
                distrito = dis["district"]
                description = ""
                name = restaurant['name']
                rating = restaurant['rating']    
                address = ', '.join(restaurant['location']['display_address'])
                categories = restaurant['categories']
                if "url" in restaurant:
                    url = restaurant["url"]
                else:
                    hours = None
                if "alias" in restaurant:
                    alias = restaurant["alias"]
                else:
                    hours = None
                if "name" in restaurant:
                    nombre = restaurant["name"]
                else:
                    nombre = None
                if "image_url" in restaurant:
                    image_url = restaurant["image_url"]
                else:
                    nombre = None
                if "is_closed" in restaurant:
                    is_closed = restaurant["is_closed"]
                else:
                    is_closed = None
                if "name" in restaurant:
                    nombre = restaurant["name"]
                else:
                    nombre = None
                if "review_count" in restaurant:
                    review_count = restaurant["review_count"]
                else:
                    review_count = None
                if "coordinates" in restaurant:
                    latitude = restaurant["coordinates"]["latitude"]
                    longitude = restaurant["coordinates"]["longitude"]
                else:
                    coordinates = None
                if "location" in restaurant:
                    location = restaurant["location"]
                else:
                    location = None
                if "display_phone" in restaurant:
                    display_phone = restaurant["display_phone"]
                else:
                    display_phone = None
                if "price" in restaurant:
                    price = restaurant["name"]
                else:
                    price = None           
                if "hours" in restaurant:
                    hours = restaurant["hours"]
                else:
                    hours = None

                
                if "transactions" in restaurant:
                    transactions = restaurant["transactions"]
                else:
                    languages = None
                if "languages" in restaurant:
                    languages = restaurant["languages"]
                else:
                    languages = None

                if "attributes" in restaurant:
                    attributes = restaurant["attributes"]
                else:
                    attributes = None

                if "transit" in restaurant:
                    transit = restaurant["transit"]
                else:
                    transit = None

                if "best_time" in restaurant:
                    best_time = restaurant["best_time"]
                else:
                    best_time = None

                if "delivery" in restaurant:
                    delivery = restaurant["delivery"]
                else:
                    delivery = None

                if "pickup" in restaurant:
                    pickup = restaurant["pickup"]
                else:
                    pickup = None

                if "online_ordering" in restaurant:
                    online_ordering = restaurant["online_ordering"]
                else:
                    online_ordering = None

                if "is_hot_and_new" in restaurant:
                    is_hot_and_new = restaurant["is_hot_and_new"]
                else:
                    is_hot_and_new = None
                

                for c in categories:
                    description = description + c["title"] + " "
                description = description  

                # Make the API call to retrieve reviews for the current business
                reviews_response = yelp_api.reviews_query(id=restaurant["id"],location="Madrid", lang="es")
                
                # Extract the reviews from the response
                reviews = reviews_response['reviews']
                
                # Process and print the reviews
                
                rev = ""
                for review in reviews[:5]:
                    review_text = review['text']
                    rating = review['rating']
                    reviewer_name = review['user']['name']

                    rev = rev + review_text + ". "   
                    
             
                res.append({
                    "name" : name, "rating": rating, "address": address, "description": description, "review": rev,
                    "distrito":distrito,
                    "alias":alias,
                    "name":nombre,
                    "image_url":image_url,
                    "is_closed":is_closed,
                    "review_count":review_count,
                    "latitude":latitude,
                    "longitude": longitude,
                    "location":location,
                    "display_phone":display_phone,
                    "price":price,
                    "hours":hours,
                    "transactions":transactions,
                    "languages":languages,
                    "attributes":attributes,
                    "transit":transit,
                    "best_time":best_time,
                    "delivery":delivery,
                    "pickup":pickup,
                    "online_ordering":online_ordering
                })
        except json.JSONDecodeError:
            print("La respuesta no es un JSON válido")
# Out:
# 40.427919 -3.680877
# 40.462428 -3.676057
# 40.466676 -3.698984

# %%
dfDistrito1 = dfDistritoX

# %%
dfDistrito1.shape
# Out:
# (20, 24)

# %%
dfDistrito2 = pd.DataFrame(res)
dfDistrito2.to_csv("../data/distrito2.csv")

# %%
df = pd.concat([dfDistrito1, dfDistrito2])
df.shape
# Out:
# (40, 24)

# %%
df.head(40)
# Out:
#                 name  rating  \
# 0        Ten con Ten       5
# 1        El Paraguas       1
# 2          Street Xo       2
# 3        Goiko Grill       4
# 4       La Tasqueria       5
# 5      InClan Brutal       5
# 6        Goiko Grill       4
# 7   Tandoori Station       5
# 8       Rosi La Loca       4
# 9         Food Truck       5
# 10           Cañadío       5
# 11     Juana la Loca       5
# 12    Celso y Manolo       5
# 13         El Barril       5
# 14    Hard Rock Cafe       5
# 15     Tinto y Tapas       5
# 16        Bar Tomate       5
# 17         La Maruca       5
# 18       La Mi Venta       5
# 19         O'Caldiño       1
# 0        Ten con Ten       5
# 1        El Paraguas       1
# 2          Street Xo       2
# 3        Goiko Grill       4
# 4       La Tasqueria       5
# 5      InClan Brutal       5
# 6        Goiko Grill       4
# 7   Tandoori Station       5
# 8       Rosi La Loca       4
# 9         Food Truck       5
# 10           Cañadío       5
# 11     Juana la Loca       5
# 12    Celso y Manolo       5
# 13         El Barril       5
# 14    Hard Rock Cafe       5
# 15     Tinto y Tapas       5
# 16        Bar Tomate       5
# 17         La Maruca       5
# 18       La Mi Venta       5
# 19         O'Caldiño       1
#
#                                               address  \
# 0              Calle de Ayala, 6, 28001 Madrid, Spain
# 1        Calle de Jorge Juan, 16, 28001 Madrid, Spain
# 2           Calle de Serrano, 52, 28001 Madrid, Spain
# 3   Calle de María de Molina, 20, 28006 Madrid, Spain
# 4       Calle Duque de Sesto, 48, 28009 Madrid, Spain
# 5          Calle Álvarez Gato, 4, 28012 Madrid, Spain
# 6    Calle Conde de Peñalver, 41, 28006 Madrid, Spain
# 7   Calle de José Ortega y Gasset, 89- 91, 28006 M...
# 8              Calle de Cádiz, 4, 28012 Madrid, Spain
# 11           220  ...     Juana la Loca   None           []      None
# 12           187  ...    Celso y Manolo   None           []      None
# 13            21  ...         El Barril   None           []      None
# 14           109  ...    Hard Rock Cafe   None           []      None
# 15           165  ...     Tinto y Tapas   None           []      None
# 16            54  ...        Bar Tomate   None           []      None
# 17            46  ...         La Maruca   None           []      None
# 18           106  ...       La Mi Venta   None           []      None
# 19            18  ...         O'Caldiño   None           []      None
#
#    attributes transit best_time delivery pickup online_ordering
# 0        None    None      None     None   None            None
# 1        None    None      None     None   None            None
# 2        None    None      None     None   None            None
# 3        None    None      None     None   None            None
# 4        None    None      None     None   None            None
# 5        None    None      None     None   None            None
# 6        None    None      None     None   None            None
# 7        None    None      None     None   None            None
# 8        None    None      None     None   None            None
# 9        None    None      None     None   None            None
# 10       None    None      None     None   None            None
# 11       None    None      None     None   None            None
# 12       None    None      None     None   None            None
# 13       None    None      None     None   None            None
# 14       None    None      None     None   None            None
# 15       None    None      None     None   None            None
# 16       None    None      None     None   None            None
# 17       None    None      None     None   None            None
# 18       None    None      None     None   None            None
# 19       None    None      None     None   None            None
# 0        None    None      None     None   None            None
# 1        None    None      None     None   None            None
# 2        None    None      None     None   None            None
# 3        None    None      None     None   None            None
# 4        None    None      None     None   None            None
# 5        None    None      None     None   None            None
# 6        None    None      None     None   None            None
# 7        None    None      None     None   None            None
# 8        None    None      None     None   None            None
# 9        None    None      None     None   None            None
# 10       None    None      None     None   None            None
# 11       None    None      None     None   None            None
# 12       None    None      None     None   None            None
# 13       None    None      None     None   None            None
# 14       None    None      None     None   None            None
# 15       None    None      None     None   None            None
# 16       None    None      None     None   None            None
# 17       None    None      None     None   None            None
# 18       None    None      None     None   None            None
# 19       None    None      None     None   None            None
#
# [40 rows x 24 columns]

# %%
dfDistritoX.columns
# Out:
# Index(['name', 'rating', 'address', 'description', 'review', 'distrito',
#        'alias', 'image_url', 'is_closed', 'review_count', 'latitude',
#        'longitude', 'location', 'display_phone', 'price', 'hours',
#        'transactions', 'languages', 'attributes', 'transit', 'best_time',
#        'delivery', 'pickup', 'online_ordering'],
#       dtype='object')

# %%
import utm
import folium
from folium import plugins 
import ipywidgets
import geocoder
import geopy

# %%
map_madrid = folium.Map(location=[40.427919,-3.680877], zoom_start=14)

for (index, row) in df.iterrows():
    folium.Marker(location = [row.loc["latitude"], row.loc["longitude"]],
    popup = "<b>"+row.loc["description"] +"</b>" + " " + row["distrito"],
    tooltip = "ver").add_to(map_madrid)

map_madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a122041a1459c3f16fe90802c9d4f817 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a122041a1459c3f16fe90802c9d4f817&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a122041a1459c3f16fe90802c9d4f817 = L.map(
#                 &quot;map_a122041a1459c3f16fe90802c9d4f817&quot;,
#                 {
#                     center: [40.427919, -3.680877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50125204ddd69ce3a854201a2c79b197 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a122041a1459c3f16fe90802c9d4f817);
#
#
#             var marker_631ebb783c0f6b7486722ebff9a992d3 = L.marker(
#                 [40.42795714, -3.68870527],
#                 {}
#             ).addTo(map_a122041a1459c3f16fe90802c9d4f817);
#
#
#         var popup_f97d1ae0cab8616d1985024ac5e25063 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53ee1ccd7b739b86e5001c241a932295 = $(`&lt;div id=&quot;html_53ee1ccd7b739b86e5001c241a932295&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Modern European &lt;/b&gt; Salamanca&lt;/div&gt;`)[0];
#                 popup_f97d1ae0cab8616d1985024ac5e25063.setContent(html_53ee1ccd7b739b86e5001c241a932295);
#
#
#
#         marker_631ebb783c0f6b7486722ebff9a992d3.bindPopup(popup_f97d1ae0cab8616d1985024ac5e25063)
#         ;
#
#
#
#
#             marker_631ebb783c0f6b7486722ebff9a992d3.bindTooltip(
#                 `&lt;div&gt;
#                      ver
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_64c637cefec5296621f3f2fb6ab80e51 = L.marker(
#                 [40.4237396136235, -3.68582059325423],
#                 {}
#             ).addTo(map_a122041a1459c3f16fe90802c9d4f817);
#
#
#         var popup_0368e72a952df2d44f1e261e6693db2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5eb38f471de72ee1668f81ea27aa40dd = $(`&lt;div id=&quot;html_5eb38f471de72ee1668f81ea27aa40dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Spanish Asturian &lt;/b&gt; Salamanca&lt;/div&gt;`)[0];
#                 popup_0368e72a952df2d44f1e261e6693db2f.setContent(html_5eb38f471de72ee1668f81ea27aa40dd);
#
#
#
#         marker_64c637cefec5296621f3f2fb6ab80e51.bindPopup(popup_0368e72a952df2d44f1e261e6693db2f)
#         ;
#
#
#
#
#             marker_64c637cefec5296621f3f2fb6ab80e51.bindTooltip(
#                 `&lt;div&gt;
#                      ver
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_770432bf52341aa6da57ff60aebe1031 = L.marker(
#                 [40.427645, -3.687092],
#                 {}
#             ).addTo(map_a122041a1459c3f16fe90802c9d4f817);
#
#
#         var popup_a5d27074aeb95992c6312bd20c83fe4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_312e06a1d008f01dbfa4f4a782f84f94 = $(`&lt;div id=&quot;html_312e06a1d008f01dbfa4f4a782f84f94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Gastropubs Asian Fusion Spanish &lt;/b&gt; Salamanca&lt;/div&gt;`)[0];
#                 popup_a5d27074aeb95992c6312bd20c83fe4e.setContent(html_312e06a1d008f01dbfa4f4a782f84f94);
#
#
#
#         marker_770432bf52341aa6da57ff60aebe1031.bindPopup(popup_a5d27074aeb95992c6312bd20c83fe4e)
#         ;
#
#
#
#
#             marker_770432bf52341aa6da57ff60aebe1031.bindTooltip(
#                 `&lt;div&gt;
#                      ver
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_442a44a29f629b0844be3579380b98fc = L.marker(
#                 [40.437668, -3.686709],
#                 {}
#             ).addTo(map_a122041a1459c3f16fe90802c9d4f817);
#
#
#         var popup_0196f281bced19269d172ca88233e5ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37d71ccfb963ba20d8f64cccf581d1f2 = $(`&lt;div id=&quot;html_37d71ccfb963ba20d8f64cccf581d1f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Burgers American (Traditional) Cafeteria &lt;/b&gt; Salamanca&lt;/div&gt;`)[0];
#                 popup_0196f281bced19269d172ca88233e5ab.setContent(html_37d71ccfb963ba20d8f64cccf581d1f2);
#
#
#
#         marker_442a44a29f629b0844be3579380b98fc.bindPopup(popup_0196f281bced19269d172ca88233e5ab)
#         ;
#
#
#
#
#             marker_442a44a29f629b0844be3579380b98fc.bindTo

# %%
dfDistritoX.to_csv("../data/distrito1.csv")
