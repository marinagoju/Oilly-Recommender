# %%
# %pip install yelpapi
# %pip install requests
# %pip install geocoder
# %pip install geopy
# Out:
# Requirement already satisfied: yelpapi in c:\python39\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\yporq\appdata\roaming\python\python39\site-packages (from yelpapi) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# Requirement already satisfied: requests in c:\users\yporq\appdata\roaming\python\python39\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# Collecting geocoder
#   Using cached geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: click in c:\python39\lib\site-packages (from geocoder) (8.1.3)
# Collecting future (from geocoder)
#   Using cached future-0.18.3.tar.gz (840 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ratelim (from geocoder)
#   Using cached ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: requests in c:\users\yporq\appdata\roaming\python\python39\site-packages (from geocoder) (2.28.2)
# Requirement already satisfied: six in c:\python39\lib\site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: colorama in c:\users\yporq\appdata\roaming\python\python39\site-packages (from click->geocoder) (0.4.6)
# Requirement already satisfied: decorator in c:\users\yporq\appdata\roaming\python\python39\site-packages (from ratelim->geocoder) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->geocoder) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->geocoder) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->geocoder) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->geocoder) (2022.12.7)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492057 sha256=dd0840bcf07ae196fb93025b94dbba150ab16953fa4fab109849541519a91930
#   Stored in directory: c:\users\yporq\appdata\local\pip\cache\wheels\bf\5d\6a\2e53874f7ec4e2bede522385439531fafec8fafe005b5c3d1b
# Successfully built future
# Installing collected packages: ratelim, future, geocoder
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] El sistema no puede encontrar el archivo especificado: 'c:\\Python39\\Scripts\\futurize.exe' -> 'c:\\Python39\\Scripts\\futurize.exe.deleteme'
# Requirement already satisfied: geopy in c:\python39\lib\site-packages (2.3.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\python39\lib\site-packages (from geopy) (2.0)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)

# %% [markdown]
# client_id, api_key

# %%
lient_id = "xloJPd8uu_wT5OA7iEGqfg"
api_key= "Q1QkFZJjdwCzYsP8JQP52gl7M-DRn1KRgVU6Fu26dHk-v8mg_jw5_ID9VDPpu7UdPhrI8RIDKFsnDq-3kZJEwi4P8KY4oTha6ibEp9_s7ODRPz50KbsFqBVzhNxlZHYx"

# %%
from yelpapi import YelpAPI
import pandas as pd
import requests
yelp_api = YelpAPI(api_key)

# %%
distritos = ['Salamanca', 'Chamartín', 'Tetuán']#, 'Salamanca', 'Chamartín', 'Tetuán', 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca', 'Latina', 'Carabanchel', 'Usera', 'Puente de Vallecas', 'Moratalaz', 'Ciudad Lineal', 'Hortaleza', 'Villaverde', 'Villa de Vallecas', 'Vicálvaro', 'San Blas-Canillejas', 'Barajas']
"""
Aída - 1,2,3 - 'Centro', 'Arganzuela', 'Retiro'
Carlos - 4,5,6 - 'Salamanca', 'Chamartín', 'Tetuán'
Marina - 7,8,9 - 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca'
Fernando - 10,11,12 - 'Latina', 'Carabanchel', 'Usera'
Víctor - 13,14,15 - 'Puente de Vallecas', 'Moratalaz', 'Ciudad Lineal'
Richi - 16,17,18 -  'Hortaleza', 'Villaverde', 'Villa de Vallecas'
Álvaro - 19,20,21 - 'Vicálvaro', 'San Blas-Canillejas', 'Barajas'

"""
# Out:
# "\nAída - 1,2,3 - 'Centro', 'Arganzuela', 'Retiro'\nCarlos - 4,5,6 - 'Salamanca', 'Chamartín', 'Tetuán'\nMarina - 7,8,9 - 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca'\nFernando - 10,11,12 - 'Latina', 'Carabanchel', 'Usera'\nVíctor - 13,14,15 - 'Puente de Vallecas', 'Moratalaz', 'Ciudad Lineal'\nRichi - 16,17,18 -  'Hortaleza', 'Villaverde', 'Villa de Vallecas'\nÁlvaro - 19,20,21 - 'Vicálvaro', 'San Blas-Canillejas', 'Barajas'\n\n"

# %%
url = 'https://api.yelp.com/v3/businesses/search'
params = {    
    'categories': 'restaurants',
    'limit': 2  # Number of results to retrieve (max is 50)
}
headers = {
    'Authorization': 'Bearer ' + api_key
}
latitude_value= 40.411390924552144
longitude_value= -3.6643494118331197
radius_value= 100

res = []
for dis in distritos:
    #params["location"] = dis + ",Madrid"
    params = {    
    "latitude": latitude_value,  # Latitud de la ubicación deseada
    "longitude": longitude_value,  # Longitud de la ubicación deseada
    "radius": radius_value,  # Radio en metros para buscar restaurantes alrededor de la ubicación
    'categories': 'restaurants',
    'limit': 2  # Number of results to retrieve (max is 50)
    }

    # Send GET request to the API
    response = requests.get(url, headers=headers, params=params)
    if response.headers.get("Content-Type") == "application/json":
        try:
            # Parse the JSON response
            data = response.json()
               # Extract and process restaurants
            restaurants = data['businesses']           
            
            for restaurant in restaurants:
                description = ""
                name = restaurant['name']
                rating = restaurant['rating']    
                address = ', '.join(restaurant['location']['display_address'])
                categories = restaurant['categories']
                if "url" in restaurant:
                    url = restaurant["url"]
                else:
                    hours = None
                if "alias" in restaurant:
                    alias = restaurant["alias"]
                else:
                    hours = None
                if "name" in restaurant:
                    nombre = restaurant["name"]
                else:
                    nombre = None
                if "image_url" in restaurant:
                    image_url = restaurant["image_url"]
                else:
                    nombre = None
                if "is_closed" in restaurant:
                    is_closed = restaurant["is_closed"]
                else:
                    is_closed = None
                if "name" in restaurant:
                    nombre = restaurant["name"]
                else:
                    nombre = None
                if "review_count" in restaurant:
                    review_count = restaurant["review_count"]
                else:
                    review_count = None
                if "coordinates" in restaurant:
                    latitude = restaurant["coordinates"]["latitude"]
                    longitude = restaurant["coordinates"]["longitude"]
                else:
                    coordinates = None
                if "location" in restaurant:
                    location = restaurant["location"]
                else:
                    location = None
                if "display_phone" in restaurant:
                    display_phone = restaurant["display_phone"]
                else:
                    display_phone = None
                if "price" in restaurant:
                    price = restaurant["name"]
                else:
                    price = None           
                if "hours" in restaurant:
                    hours = restaurant["hours"]
                else:
                    hours = None

                
                if "transactions" in restaurant:
                    transactions = restaurant["transactions"]
                else:
                    languages = None
                if "languages" in restaurant:
                    languages = restaurant["languages"]
                else:
                    languages = None

                if "attributes" in restaurant:
                    attributes = restaurant["attributes"]
                else:
                    attributes = None

                if "transit" in restaurant:
                    transit = restaurant["transit"]
                else:
                    transit = None

                if "best_time" in restaurant:
                    best_time = restaurant["best_time"]
                else:
                    best_time = None

                if "delivery" in restaurant:
                    delivery = restaurant["delivery"]
                else:
                    delivery = None

                if "pickup" in restaurant:
                    pickup = restaurant["pickup"]
                else:
                    pickup = None

                if "online_ordering" in restaurant:
                    online_ordering = restaurant["online_ordering"]
                else:
                    online_ordering = None

                if "is_hot_and_new" in restaurant:
                    is_hot_and_new = restaurant["is_hot_and_new"]
                else:
                    is_hot_and_new = None
                

                for c in categories:
                    description = description + c["title"] + " "
                description = description  

                # Make the API call to retrieve reviews for the current business
                reviews_response = yelp_api.reviews_query(id=restaurant["id"],location="Madrid", lang="es")
                
                # Extract the reviews from the response
                reviews = reviews_response['reviews']
                
                # Process and print the reviews
                
                rev = ""
                for review in reviews[:5]:
                    review_text = review['text']
                    rating = review['rating']
                    reviewer_name = review['user']['name']

                    rev = rev + review_text + ". "   
                    
             
                res.append({
                    "name" : name, "rating": rating, "address": address, "description": description, "review": rev,
                    "alias":alias,
                    "name":nombre,
                    "image_url":image_url,
                    "is_closed":is_closed,
                    "review_count":review_count,
                    "latitude":latitude,
                    "longitude": longitude,
                    "location":location,
                    "display_phone":display_phone,
                    "price":price,
                    "hours":hours,
                    "transactions":transactions,
                    "languages":languages,
                    "attributes":attributes,
                    "transit":transit,
                    "best_time":best_time,
                    "delivery":delivery,
                    "pickup":pickup,
                    "online_ordering":online_ordering
                })
        except json.JSONDecodeError:
            print("La respuesta no es un JSON válido")

dfDistritoX = pd.DataFrame(res)

# %%
dfDistritoX = pd.DataFrame(res)

# %%
dfDistritoX.head()
# Out:
#     name  rating                               address         description  \
# 0  Norba     4.0  Calle Sirio, 26, 28007 Madrid, Spain  Spanish Wine Bars
#
#   review         alias                                          image_url  \
# 0         norba-madrid  https://s3-media1.fl.yelpcdn.com/bphoto/gLxaRr...
#
#    is_closed  review_count   latitude  ...  price hours transactions  \
# 0      False             1  40.412098  ...   None  None           []
#
#   languages attributes transit best_time delivery pickup online_ordering
# 0      None       None    None      None     None   None            None
#
# [1 rows x 23 columns]

# %%
dfDistritoX.latitude
# Out:
# 0    40.412098
# Name: latitude, dtype: float64

# %%
# %pip install --no-cache-dir geocoder
# Out:
# Requirement already satisfied: geocoder in c:\python39\lib\site-packages (1.38.1)
# Requirement already satisfied: click in c:\python39\lib\site-packages (from geocoder) (8.1.3)
# Requirement already satisfied: future in c:\python39\lib\site-packages (from geocoder) (0.18.3)
# Requirement already satisfied: ratelim in c:\python39\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in c:\users\yporq\appdata\roaming\python\python39\site-packages (from geocoder) (2.28.2)
# Requirement already satisfied: six in c:\python39\lib\site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: colorama in c:\users\yporq\appdata\roaming\python\python39\site-packages (from click->geocoder) (0.4.6)
# Requirement already satisfied: decorator in c:\users\yporq\appdata\roaming\python\python39\site-packages (from ratelim->geocoder) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->geocoder) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->geocoder) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->geocoder) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->geocoder) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)

# %%
import utm
import folium
from folium import plugins 
import ipywidgets
import geocoder
import geopy

# %%
map_madrid = folium.Map(location=[40.427919,-3.680877], zoom_start=14)

for (index, row) in dfDistritoX.iterrows():
    folium.Marker(location = [row.loc["latitude"], row.loc["longitude"]],
    #popup = row.loc["rotulo"] + " " + row["desc_distrito_local"],
    tooltip = "click").add_to(map_madrid)

map_madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3c8dc356091add75159092cbc90b7a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3c8dc356091add75159092cbc90b7a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3c8dc356091add75159092cbc90b7a9 = L.map(
#                 &quot;map_d3c8dc356091add75159092cbc90b7a9&quot;,
#                 {
#                     center: [40.427919, -3.680877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2c44145e807bf75d5860e2d63b381be = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             var marker_b6fa570c2eae4cba753dfa93833734c6 = L.marker(
#                 [40.41406, -3.70803],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_b6fa570c2eae4cba753dfa93833734c6.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_10b0cdbbe997963b95ed27c2c2a1a552 = L.marker(
#                 [40.412325, -3.709429],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_10b0cdbbe997963b95ed27c2c2a1a552.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3c8b9b93679c6888233dd6dfcc4015e9 = L.marker(
#                 [40.4113584, -3.711094],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_3c8b9b93679c6888233dd6dfcc4015e9.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b43ca7014af096d8b4ad78fa0c52bd86 = L.marker(
#                 [40.4167599, -3.7068],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_b43ca7014af096d8b4ad78fa0c52bd86.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d55cb55152677100ae1ae37fc5d3aa8a = L.marker(
#                 [40.4158141746249, -3.70297881289753],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_d55cb55152677100ae1ae37fc5d3aa8a.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0686213dafaa58c780559fb5319117db = L.marker(
#                 [40.41508, -3.70192],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_0686213dafaa58c780559fb5319117db.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a379dea2851c047005650c6c4d36f91d = L.marker(
#                 [40.414641, -3.706778],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_a379dea2851c047005650c6c4d36f91d.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2ff6c04ca41d9105a2ca305b43ac1dcd = L.marker(
#                 [40.4204554916193, -3.71240258216858],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_2ff6c04ca41d9105a2ca305b43ac1dcd.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aa667a24427c01cbe4a22942c0001e26 = L.marker(
#                 [40.41611, -3.70744],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_aa667a24427c01cbe4a22942c0001e26.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_669b6dea2c30405837a0878330030e0d = L.marker(
#                 [40.415006, -3.708161],
#                 {}
#             ).addTo(map_d3c8dc356091add75159092cbc90b7a9);
#
#
#             marker_669b6dea2c304058

# %%
dfDistritoX.to_csv("../data/distritoX.csv")
