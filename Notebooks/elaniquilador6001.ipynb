# %% [markdown]
# client_id, api_key

# %%
from yelpapi import YelpAPI
import pandas as pd
import requests
yelp_api = YelpAPI(api_key)

# %%
distritos = ['Salamanca', 'Chamartín', 'Tetuán']#, 'Salamanca', 'Chamartín', 'Tetuán', 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca', 'Latina', 'Carabanchel', 'Usera', 'Puente de Vallecas', 'Moratalaz', 'Ciudad Lineal', 'Hortaleza', 'Villaverde', 'Villa de Vallecas', 'Vicálvaro', 'San Blas-Canillejas', 'Barajas']
"""
Aída - 1,2,3 - 'Centro', 'Arganzuela', 'Retiro'
Carlos - 4,5,6 - 'Salamanca', 'Chamartín', 'Tetuán'
Marina - 7,8,9 - 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca'
Fernando - 10,11,12 - 'Latina', 'Carabanchel', 'Usera'
Víctor - 13,14,15 - 'Puente de Vallecas', 'Moratalaz', 'Ciudad Lineal'
Richi - 16,17,18 -  'Hortaleza', 'Villaverde', 'Villa de Vallecas'
Álvaro - 19,20,21 - 'Vicálvaro', 'San Blas-Canillejas', 'Barajas'

"""
# Out:
# "\nAída - 1,2,3 - 'Centro', 'Arganzuela', 'Retiro'\nCarlos - 4,5,6 - 'Salamanca', 'Chamartín', 'Tetuán'\nMarina - 7,8,9 - 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca'\nFernando - 10,11,12 - 'Latina', 'Carabanchel', 'Usera'\nVíctor - 13,14,15 - 'Puente de Vallecas', 'Moratalaz', 'Ciudad Lineal'\nRichi - 16,17,18 -  'Hortaleza', 'Villaverde', 'Villa de Vallecas'\nÁlvaro - 19,20,21 - 'Vicálvaro', 'San Blas-Canillejas', 'Barajas'\n\n"

# %% [markdown]
# districts = [
#     {"district": "Centro", "latitude": 40.415363, "longitude": -3.707398},
#     {"district": "Arganzuela", "latitude": 40.398068, "longitude": -3.693734},
#     {"district": "Retiro", "latitude": 40.411894, "longitude": -3.676574},
#     {"district": "Salamanca", "latitude": 40.427919, "longitude": -3.680877},
#     {"district": "Chamartín", "latitude": 40.462428, "longitude": -3.676057},
#     {"district": "Tetuán", "latitude": 40.466676, "longitude": -3.698984},
#     {"district": "Chamberí", "latitude": 40.436247, "longitude": -3.703830},
#     {"district": "Fuencarral-El Pardo", "latitude": 40.515923, "longitude": -3.785586},
#     {"district": "Moncloa-Aravaca", "latitude": 40.439883, "longitude": -3.744509},
#     {"district": "Latina", "latitude": 40.388981, "longitude": -3.753525},
#     {"district": "Carabanchel", "latitude": 40.377818, "longitude": -3.751209},
#     {"district": "Usera", "latitude": 40.383553, "longitude": -3.706070},
#     {"district": "Puente de Vallecas", "latitude": 40.389491, "longitude": -3.669062},
#     {"district": "Moratalaz", "latitude": 40.407251, "longitude": -3.644992},
#     {"district": "Ciudad Lineal", "latitude": 40.448431, "longitude": -3.650495},
#     {"district": "Hortaleza", "latitude": 40.474457, "longitude": -3.640892},
#     {"district": "Villaverde", "latitude": 40.345610, "longitude": -3.695956},
#     {"district": "Villa de Vallecas", "latitude": 40.367040, "longitude": -3.612046},
#     {"district": "Vicálvaro", "latitude": 40.396584, "longitude": -3.576622},
#     {"district": "San Blas-Canillejas", "latitude": 40.428918, "longitude": -3.609064},
#     {"district": "Barajas", "latitude": 40.477628, "longitude": -3.579394}
# ]

# %%
pd.set_option('display.max_columns',None)

# %%
url = 'https://api.yelp.com/v3/businesses/search'
params = {    
    'categories': 'restaurants',
    'limit': 50  # Number of results to retrieve (max is 50)
}
headers = {
    'Authorization': 'Bearer ' + api_key
}
salamanca= 40.427919,-3.680877
chamartin= 40.462428,-3.676057
tetuan= 40.466676,-3.698984


latitude_value= 40.466676#salamanca
longitude_value= -3.698984#salamanca
radius_value= 2000

res = []
for dis in distritos:
    #params["location"] = dis + ",Madrid"
    params = {    
    "latitude": latitude_value,  # Latitud de la ubicación deseada
    "longitude": longitude_value,  # Longitud de la ubicación deseada
    "radius": radius_value,  # Radio en metros para buscar restaurantes alrededor de la ubicación
    'categories': 'restaurants',
    'limit': 50,  # Number of results to retrieve (max is 50)
    'attributes': "hours",

    }


    # Send GET request to the API
    response = requests.get(url, headers=headers, params=params)
    if response.headers.get("Content-Type") == "application/json":
        try:
            # Parse the JSON response
            data = response.json()
               # Extract and process restaurants
            restaurants = data['businesses']           
            
            for restaurant in restaurants:
                description = ""
                name = restaurant['name']
                rating = restaurant['rating']    
                address = ', '.join(restaurant['location']['display_address'])
                categories = restaurant['categories']
                
                if "url" in restaurant:
                    url = restaurant["url"]
                else:
                    hours = None
                if "alias" in restaurant:
                    alias = restaurant["alias"]
                else:
                    hours = None
                if "name" in restaurant:
                    nombre = restaurant["name"]
                else:
                    nombre = None
                if "image_url" in restaurant:
                    image_url = restaurant["image_url"]
                else:
                    nombre = None
                if "is_closed" in restaurant:
                    is_closed = restaurant["is_closed"]
                else:
                    is_closed = None
                if "name" in restaurant:
                    nombre = restaurant["name"]
                else:
                    nombre = None
                if "review_count" in restaurant:
                    review_count = restaurant["review_count"]
                else:
                    review_count = None
                if "coordinates" in restaurant:
                    latitude = restaurant["coordinates"]["latitude"]
                    longitude = restaurant["coordinates"]["longitude"]
                else:
                    coordinates = None
                if "location" in restaurant:
                    location = restaurant["location"]
                else:
                    location = None
                if "display_phone" in restaurant:
                    display_phone = restaurant["display_phone"]
                else:
                    display_phone = None
                if "price" in restaurant:
                    price = restaurant["price"]
                else:
                    price = None           
                if "hours" in restaurant:
                    hours = restaurant["hours"]
                else:
                    hours = None
                if "transactions" in restaurant:
                    transactions = restaurant["transactions"]
                else:
                    languages = None
                if "languages" in restaurant:
                    languages = restaurant["languages"]
                else:
                    languages = None

                if "attributes" in restaurant:
                    attributes = restaurant["attributes"]
                else:
                    attributes = None

                if "transit" in restaurant:
                    transit = restaurant["transit"]
                else:
                    transit = None

                if "best_time" in restaurant:
                    best_time = restaurant["best_time"]
                else:
                    best_time = None

                if "delivery" in restaurant:
                    delivery = restaurant["delivery"]
                else:
                    delivery = None

                if "pickup" in restaurant:
                    pickup = restaurant["pickup"]
                else:
                    pickup = None

                if "online_ordering" in restaurant:
                    online_ordering = restaurant["online_ordering"]
                else:
                    online_ordering = None

                if "is_hot_and_new" in restaurant:
                    is_hot_and_new = restaurant["is_hot_and_new"]
                else:
                    is_hot_and_new = None
                

                for c in categories:
                    description = description + c["title"] + " "
                description = description  

                # Make the API call to retrieve reviews for the current business
                reviews_response = yelp_api.reviews_query(id=restaurant["id"],location="Madrid", lang="es")
                
                # Extract the reviews from the response
                reviews = reviews_response['reviews']
                
                # Process and print the reviews
                
                rev = ""
                for review in reviews[:5]:
                    review_text = review['text']
                    rating = review['rating']
                    reviewer_name = review['user']['name']

                    rev = rev + review_text + ". "   
                    
             
                res.append({
                    "name" : name, "rating": rating, "address": address, "description": description, "review": rev,
                    "alias":alias,
                    "name":nombre,
                    "image_url":image_url,
                    "is_closed":is_closed,
                    "review_count":review_count,
                    "latitude":latitude,
                    "longitude": longitude,
                    "location":location,
                    "display_phone":display_phone,
                    "price":price,
                    "hours":hours,
                    "transactions":transactions,
                    "languages":languages,
                    "attributes":attributes,
                    "transit":transit,
                    "best_time":best_time,
                    "delivery":delivery,
                    "pickup":pickup,
                    "online_ordering":online_ordering
                })
        except json.JSONDecodeError:
            print("La respuesta no es un JSON válido")

dfDistritoX = pd.DataFrame(res)

# %%
dfDistritoX = pd.DataFrame(res)

# %%
dfDistritoX.head(25)
# Out:
#                          name  rating  \
# 0          Asador Donostiarra     4.0
# 1                     Diverxo     5.0
# 2                  L'Albufera     5.0
# 3                      Tierra     5.0
# 4                 Goiko Grill     4.0
# 5                    De María     5.0
# 6          Alfredo's Barbacoa     4.0
# 7                      Matcha     5.0
# 8                   Casa Juan     5.0
# 9             New York Burger     2.0
# 10                 La Chalana     5.0
# 11     Don Lisander Trattoria     4.0
# 12            New York Burger     3.0
# 13  La Cantina de la Estación     5.0
# 14                 Santceloni     5.0
# 15              Naked & Sated     5.0
# 16                Vaca Nostra     5.0
# 17               Nitty Gritty     4.0
# 18             La Antequerana     4.0
# 19                 5 Cucharas     5.0
# 20               Shangai Mama     5.0
# 21             Piccola Napoli     5.0
# 22                   Rubaiyat     5.0
# 23           Taxi a Manhattan     1.0
# 24            Home Burger Bar     5.0
#
#                                               address  \
# 0   Calle de la Infanta Mercedes, 79, 28020 Madrid...
# 1         Calle Padre Damián, 23, 28020 Madrid, Spain
# 2   Calle Poeta Joan Maragall, 43, 28020 Madrid, S...
# 3        Calle de San Germán, 12, 28020 Madrid, Spain
# 4   Avenida del General Perón, 16, 28020 Madrid, S...
# 5            Calle Félix Boix, 5, 28036 Madrid, Spain
# 6   Calle de Juan Hurtado de Mendoza, 11, 28036 Ma...
# 7   Calle de la Infanta Mercedes, 62, 28020 Madrid...
# 8   Calle de la Infanta Mercedes, 111, 28020 Madri...
# 9     Calle del General Yagüe, 5, 28020 Madrid, Spain
# 10   Paseo de La Castellana, 179, 28046 Madrid, Spain
# 11  Calle de la Infanta Mercedes, 92, 28020 Madrid...
# 12    Paseo de la Castellana, 89, 28046 Madrid, Spain
# 13  Calle de Sor Angela de la Cruz, 17, 28020 Madr...
# 12  {'address1': 'Paseo de la Castellana, 89', 'ad...  +34 917 70 79 82     €
# 13  {'address1': 'Calle de Sor Angela de la Cruz, ...  +34 915 70 65 45    €€
# 14  {'address1': 'Paseo de la Castellana, 57', 'ad...  +34 912 10 88 40  €€€€
# 15  {'address1': 'Calle Estébanez Calderón, 3-5', ...  +34 914 67 57 63  None
# 16  {'address1': 'Paseo de la Castellana, 257', 'a...  +34 913 78 88 06  None
# 17  {'address1': 'Calle Doctor Fleming, 51', 'addr...  +34 914 34 73 33    €€
# 18  {'address1': 'Calle de Sor Ángela de la Cruz, ...  +34 915 67 20 66     €
# 19  {'address1': 'Calle de la Infanta Mercedes, 11...  +34 677 81 78 72   €€€
# 20  {'address1': 'Calle de la Infanta Mercedes, 62...  +34 910 41 87 28  None
# 21  {'address1': 'Calle Palencia, 29', 'address2':...  +34 911 43 71 21    €€
# 22  {'address1': 'Calle de Juan Ramón Jiménez, 37'...  +34 913 59 56 96   €€€
# 23  {'address1': 'Calle de la Basílica, 17', 'addr...  +34 918 33 40 34    €€
# 24  {'address1': 'Paseo de la Castellana, 210', 'a...  +34 912 19 56 58    €€
#
#    hours transactions languages attributes transit best_time delivery pickup  \
# 0   None           []      None       None    None      None     None   None
# 1   None           []      None       None    None      None     None   None
# 2   None           []      None       None    None      None     None   None
# 3   None           []      None       None    None      None     None   None
# 4   None           []      None       None    None      None     None   None
# 5   None           []      None       None    None      None     None   None
# 6   None           []      None       None    None      None     None   None
# 7   None           []      None       None    None      None     None   None
# 8   None           []      None       None    None      None     None   None
# 9   None           []      None       None    None      None     None   None
# 10  None           []      None       None    None      None     None   None
# 11  None           []      None       None    None      None     None   None
# 12  None           []      None       None    None      None     None   None
# 13  None           []      None       None    None      None     None   None
# 14  None           []      None       None    None      None     None   None
# 15  None           []      None       None    None      None     None   None
# 16  None           []      None       None    None      None     None   None
# 17  None           []      None       None    None      None     None   None
# 18  None           []      None       None    None      None     None   None
# 19  None           []      None       None    None      None     None   None
# 20  None           []      None       None    None      None     None   None
# 21  None           []      None       None    None      None     None   None
# 22  None           []      None       None    None      None     None   None
# 23  None           []      None       None    None      None     None   None
# 24  None           []      None       None    None      None     None   None
#
#    online_ordering
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# 5             None
# 6             None
# 7             None
# 8             None
# 9             None
# 10            None
# 11            None
# 12            None
# 13            None
# 14            None
# 15            None
# 16            None
# 17            None
# 18            None
# 19            None
# 20            None
# 21            None
# 22            None
# 23            None
# 24            None

# %%
import utm
import folium
from folium import plugins 
import ipywidgets
import geocoder
import geopy

# %%
map_madrid = folium.Map(location=[40.427919,-3.680877], zoom_start=14)

for (index, row) in dfDistritoX.iterrows():
    folium.Marker(location = [row.loc["latitude"], row.loc["longitude"]],
    #popup = row.loc["rotulo"] + " " + row["desc_distrito_local"],
    tooltip = "click").add_to(map_madrid)

map_madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ea810b93b517ec236c16e173cf06813 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ea810b93b517ec236c16e173cf06813&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ea810b93b517ec236c16e173cf06813 = L.map(
#                 &quot;map_3ea810b93b517ec236c16e173cf06813&quot;,
#                 {
#                     center: [40.427919, -3.680877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f183405b9458ea250eb5b1880666cb6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             var marker_8b61d78ec77a7f0734a2a037b740abfe = L.marker(
#                 [40.4618550274638, -3.69583844582038],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             marker_8b61d78ec77a7f0734a2a037b740abfe.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c3032433210cb6e69bff32bb0c934d86 = L.marker(
#                 [40.457888263931, -3.68604997698104],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             marker_c3032433210cb6e69bff32bb0c934d86.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4935a7f89c13acb85140573a604c8529 = L.marker(
#                 [40.4614403, -3.6921475],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             marker_4935a7f89c13acb85140573a604c8529.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_32daee340e22a43d751c521355c5ef4f = L.marker(
#                 [40.45645, -3.69292],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             marker_32daee340e22a43d751c521355c5ef4f.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d9268b84844e00c2c60728ca676e35fa = L.marker(
#                 [40.45225, -3.69695],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             marker_d9268b84844e00c2c60728ca676e35fa.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7e8b6fe3836a931e69689114e65429fe = L.marker(
#                 [40.4634705, -3.68821],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             marker_7e8b6fe3836a931e69689114e65429fe.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3e437ee3b60115da3f24b8ccfe321d54 = L.marker(
#                 [40.460491958998, -3.6872518199854],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             marker_3e437ee3b60115da3f24b8ccfe321d54.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_54032a94a84ae5997762763b33de183a = L.marker(
#                 [40.460297014489, -3.69667736120842],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             marker_54032a94a84ae5997762763b33de183a.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_92f7340cc9836abc4430ffac16abe74f = L.marker(
#                 [40.4639922, -3.6932226],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);
#
#
#             marker_92f7340cc9836abc4430ffac16abe74f.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_24cf0ab3bce41eb548574695ab28cf60 = L.marker(
#                 [40.4560690983281, -3.69281826683173],
#                 {}
#             ).addTo(map_3ea810b93b517ec236c16e173cf06813);

# %%
dfDistritoX.to_csv("../data/tetuan.csv")

# %%
dfDistritoX.review[0]
# Out:
# 'Stayed in Madrid for 8 days. Must have tried 15 different restaurants. NOTHING I MEAN NOTHING compares to A Donoatria. The service, the food THE FOOD!!!!.... Another Madrid gem to be discovered. Bask country style in Madrid financial and business area. Great Menu. Nice and generous portions\nExcellent for business.... Great place. The quality of the ingreafiebts is exceptional. Traditional asador Spanish food. Ceremonial serving. Familiar to Real Madrid players.. '

# %%
first_restaurant_reviews = dfDistritoX['review'].iloc[0]

# %%
print(first_restaurant_reviews)
# Out:
# Stayed in Madrid for 8 days. Must have tried 15 different restaurants. NOTHING I MEAN NOTHING compares to A Donoatria. The service, the food THE FOOD!!!!.... Another Madrid gem to be discovered. Bask country style in Madrid financial and business area. Great Menu. Nice and generous portions
# Excellent for business.... Great place. The quality of the ingreafiebts is exceptional. Traditional asador Spanish food. Ceremonial serving. Familiar to Real Madrid players..

# %%
first_restaurant_reviews = dfDistritoX['review'].iloc[0]

# %%
print(first_restaurant_reviews)
# Out:
# Stayed in Madrid for 8 days. Must have tried 15 different restaurants. NOTHING I MEAN NOTHING compares to A Donoatria. The service, the food THE FOOD!!!!.... Another Madrid gem to be discovered. Bask country style in Madrid financial and business area. Great Menu. Nice and generous portions
# Excellent for business.... Great place. The quality of the ingreafiebts is exceptional. Traditional asador Spanish food. Ceremonial serving. Familiar to Real Madrid players..
