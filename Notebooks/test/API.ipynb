# %%
import pandas as pd 
import numpy as np

# %%
import pandas as pd
import requests

# Set up the API endpoint and parameters
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "key": "AIzaSyCWkLShgoN-TsAnpDOlWoQC0UVSVh_2PH8",
    "location": "40.430082480960316, -3.6984050606684566",
    "radius": 1500,
    "type": "restaurant"
}

# Send the request to the API
response = requests.get(url, params=params)

# Get the JSON response
data = response.json()

# Initialize lists to store data
names = []
addresses = []
ratings = []
types_list = []
reviews_list = []
website= []

# Process the response
if "results" in data:
    for result in data["results"]:
        names.append(result.get("name", "N/A"))
        addresses.append(result.get("vicinity", "N/A"))
        ratings.append(result.get("rating", "N/A"))
        types_list.append(result.get("types", "N/A"))
        #reviews = result.get("reviews", [])
        #reviews_text = "\n".join([review["text"] for review in reviews])
        reviews_list.append(result.get("reviews", "N/A"))
        website.append(result.get("website", "N/A"))

# Create a DataFrame from the lists
df = pd.DataFrame({
    "Name": names,
    "Address": addresses,
    "Rating": ratings,
    "Types": types_list,
    "Reviews": reviews_list,
    "Website": website,
})

# Print the DataFrame
print(df)
# Out:
#                                                  Name  \
# 0                                           Sagaretxe
# 1                                              Miyama
# 2                          Petit Palace Santa Barbara
# 3                                             bolivar
# 4                                        ICON Embassy
# 5                                  Hotel Único Madrid
# 6   Taste Me TM - Bar Restaurante con terraza en C...
# 7                              Restaurante Bar Tomate
# 8                          El Pedrusco de Aldealcorvo
# 9                                  La Fragua de Sebín
# 10                                              Ojalá
# 11                                         La Mordida
# 12                              Taberna La Carmencita
# 13                                   La Musa Malasaña
# 14                             La Esquina de Chamberí
# 15                Restaurante Las Tortillas de Gabino
# ...

# %%
df
# Out:
#                                                  Name  \
# 0                                           Sagaretxe
# 1                                              Miyama
# 2                          Petit Palace Santa Barbara
# 3                                             bolivar
# 4                                        ICON Embassy
# 5                                  Hotel Único Madrid
# 6   Taste Me TM - Bar Restaurante con terraza en C...
# 7                              Restaurante Bar Tomate
# 8                          El Pedrusco de Aldealcorvo
# 9                                  La Fragua de Sebín
# 10                                              Ojalá
# 11                                         La Mordida
# 12                              Taberna La Carmencita
# 13                                   La Musa Malasaña
# 14                             La Esquina de Chamberí
# 15                Restaurante Las Tortillas de Gabino
# ...

# %%
import pandas as pd
import requests

# Set up the API endpoint and parameters
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "key": "AIzaSyCWkLShgoN-TsAnpDOlWoQC0UVSVh_2PH8",
    "location": "40.4220966,-3.7069043",
    "radius": 1500,
    "type": "restaurant"
}

# Send the request to the API
response = requests.get(url, params=params)

# Get the JSON response
data = response.json()

# Initialize lists to store data
names = []
addresses = []
ratings = []
types_list = []
reviews_list = []
place_id = []

# Process the response
if "results" in data:
    for result in data["results"]:
        names.append(result.get("name", "N/A"))
        addresses.append(result.get("vicinity", "N/A"))
        ratings.append(result.get("rating", "N/A"))
        types_list.append(result.get("types", "N/A"))
        reviews_list.append(result.get("reviews"))
        place_id.append(result.get("place_id", "N/A"))

# Create a DataFrame from the lists
mf = pd.DataFrame({
    "Name": names,
    "Address": addresses,
    "Rating": ratings,
    "Types": types_list,
    "Reviews": reviews_list,
    "Place_id": place_id
})

# Print the DataFrame
print(mf)
# Out:
#                                   Name  \
# 0                   Restaurante Krüger
# 1                 La Chulapa de Alcalá
# 2     Taberna del Alabardero de Madrid
# 3                 Corral de la Morería
# 4       Hotel Intur Palacio San Martín
# 5           Petit Palace Santa Barbara
# 6               Posada del León de Oro
# 7                  La Esquina del Real
# 8                              bolivar
# 9                    Miyama Restaurant
# 10                           Sagaretxe
# 11                    Lamucca de Prado
# 12                 Mercado de la Reina
# 13              La Capilla De La Bolsa
# 14                      El Club Allard
# 15  Taberna de la Daniela - Medinaceli
# 16                  Da Nicola Gran Vía
# 17                  La Fragua de Sebín
# 18                                Ribs
# 19               Taberna La Carmencita
#
#                                       Address  Rating  \
# 0             Calle de la Princesa, 5, Madrid     3.9
# ...

# %%
mf
# Out:
#                                   Name  \
# 0                   Restaurante Krüger
# 1                 La Chulapa de Alcalá
# 2     Taberna del Alabardero de Madrid
# 3                 Corral de la Morería
# 4       Hotel Intur Palacio San Martín
# 5           Petit Palace Santa Barbara
# 6               Posada del León de Oro
# 7                  La Esquina del Real
# 8                              bolivar
# 9                    Miyama Restaurant
# 10                           Sagaretxe
# 11                    Lamucca de Prado
# 12                 Mercado de la Reina
# 13              La Capilla De La Bolsa
# 14                      El Club Allard
# 15  Taberna de la Daniela - Medinaceli
# 16                  Da Nicola Gran Vía
# 17                  La Fragua de Sebín
# 18                                Ribs
# 19               Taberna La Carmencita
#
#                                       Address  Rating  \
# 0             Calle de la Princesa, 5, Madrid     3.9
# ...
