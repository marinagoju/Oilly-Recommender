# %%
# %pip install yelpapi
# %pip install requests
# Out:
# Requirement already satisfied: yelpapi in c:\python39\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\yporq\appdata\roaming\python\python39\site-packages (from yelpapi) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests->yelpapi) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# Requirement already satisfied: requests in c:\users\yporq\appdata\roaming\python\python39\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yporq\appdata\roaming\python\python39\site-packages (from requests) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)

# %% [markdown]
# client_id, api_key

# %%
client_id= "vL5ilzAI2YveKPb6Bw-73w"
api_key = "amkwPE-svNE5YEY-1FDPeQQn8vg3q-HkkIZw7QBTB_2NpjmxSSXi0IDwOQDTQNCB2celgcn1batntEiQacr-p1KBABxF-DX3L20hexQBTElKuQ6VpmkkT1I0BqBkZHYx"

# %%
from yelpapi import YelpAPI
import pandas as pd
import requests
yelp_api = YelpAPI(api_key)

# %%
distritos = [
    {"district": "Centro", "latitude": 40.415363, "longitude": -3.707398},
    {"district": "Arganzuela", "latitude": 40.398068, "longitude": -3.693734},
    {"district": "Retiro", "latitude": 40.411894, "longitude": -3.676574},
    {"district": "Salamanca", "latitude": 40.427919, "longitude": -3.680877},
    {"district": "Chamartín", "latitude": 40.462428, "longitude": -3.676057},
    {"district": "Tetuán", "latitude": 40.466676, "longitude": -3.698984},
    {"district": "Chamberí", "latitude": 40.436247, "longitude": -3.703830},
    {"district": "Fuencarral-El Pardo", "latitude": 40.515923, "longitude": -3.785586},
    {"district": "Moncloa-Aravaca", "latitude": 40.439883, "longitude": -3.744509},
    {"district": "Latina", "latitude": 40.388981, "longitude": -3.753525},
    {"district": "Carabanchel", "latitude": 40.377818, "longitude": -3.751209},
    {"district": "Usera", "latitude": 40.383553, "longitude": -3.706070},
    {"district": "Puente de Vallecas", "latitude": 40.389491, "longitude": -3.669062},
    {"district": "Moratalaz", "latitude": 40.407251, "longitude": -3.644992},
    {"district": "Ciudad Lineal", "latitude": 40.448431, "longitude": -3.650495},
    {"district": "Hortaleza", "latitude": 40.474457, "longitude": -3.640892},
    {"district": "Villaverde", "latitude": 40.345610, "longitude": -3.695956},
    {"district": "Villa de Vallecas", "latitude": 40.367040, "longitude": -3.612046},
    {"district": "Vicálvaro", "latitude": 40.396584, "longitude": -3.576622},
    {"district": "San Blas-Canillejas", "latitude": 40.428918, "longitude": -3.609064},
    {"district": "Barajas", "latitude": 40.477628, "longitude": -3.579394}
]

# %%
distritos[0]["district"]
# Out:
# 'Centro'

# %%
url = 'https://api.yelp.com/v3/businesses/search'
params = {
    'location': 'vicalvaro,Madrid',
    'categories': 'restaurants',
    'limit': 50  # Number of results to retrieve (max is 50)
}
headers = {
    'Authorization': 'Bearer ' + api_key
}
res = []
for dis in distritos[:3]:  
    params = {  
        "latitude": dis["latitude"],
        "longitude": dis["longitude"]        
    }
  
    # Send GET request to the API
    response = requests.get(url, headers=headers, params=params)
    if response.headers.get("Content-Type") == "application/json":
        try:
            # Parse the JSON response
            data = response.json()
           
            # Extract and process restaurants
            restaurants = data['businesses']           
            print(dis["district"], len(restaurants))
            for restaurant in restaurants:
                distrito = dis["district"]
              
                description = ""
                name = restaurant['name']
                rating = restaurant['rating']    
                address = ', '.join(restaurant['location']['display_address'])
                categories = restaurant['categories']
                if "url" in restaurant:
                    url = restaurant["url"]
                else:
                    hours = None
                if "alias" in restaurant:
                    alias = restaurant["alias"]
                else:
                    hours = None
                if "name" in restaurant:
                    nombre = restaurant["name"]
                else:
                    nombre = None
                if "image_url" in restaurant:
                    image_url = restaurant["image_url"]
                else:
                    nombre = None
                if "is_closed" in restaurant:
                    is_closed = restaurant["is_closed"]
                else:
                    is_closed = None
                if "name" in restaurant:
                    nombre = restaurant["name"]
                else:
                    nombre = None
                if "review_count" in restaurant:
                    review_count = restaurant["review_count"]
                else:
                    review_count = None
                if "coordinates" in restaurant:
                    latitude = restaurant["coordinates"]["latitude"]
                    longitude = restaurant["coordinates"]["longitude"]
                else:
                    coordinates = None
                if "location" in restaurant:
                    location = restaurant["location"]
                else:
                    location = None
                if "display_phone" in restaurant:
                    display_phone = restaurant["display_phone"]
                else:
                    display_phone = None
                if "price" in restaurant:
                    price = restaurant["price"]
                else:
                    price = None           
                if "hours" in restaurant:
                    hours = restaurant["hours"]
                else:
                    hours = None

                
                if "transactions" in restaurant:
                    transactions = restaurant["transactions"]
                else:
                    languages = None
                if "languages" in restaurant:
                    languages = restaurant["languages"]
                else:
                    languages = None

                if "attributes" in restaurant:
                    attributes = restaurant["attributes"]
                else:
                    attributes = None

                if "transit" in restaurant:
                    transit = restaurant["transit"]
                else:
                    transit = None

                if "best_time" in restaurant:
                    best_time = restaurant["best_time"]
                else:
                    best_time = None

                if "delivery" in restaurant:
                    delivery = restaurant["delivery"]
                else:
                    delivery = None

                if "pickup" in restaurant:
                    pickup = restaurant["pickup"]
                else:
                    pickup = None

                if "online_ordering" in restaurant:
                    online_ordering = restaurant["online_ordering"]
                else:
                    online_ordering = None

                if "is_hot_and_new" in restaurant:
                    is_hot_and_new = restaurant["is_hot_and_new"]
                else:
                    is_hot_and_new = None
                

                for c in categories:
                    description = description + c["title"] + " "
                description = description  

                # Make the API call to retrieve reviews for the current business
                reviews_response = yelp_api.reviews_query(id=restaurant["id"],location="Madrid", lang="es")
                
                # Extract the reviews from the response
                reviews = reviews_response['reviews']
                
                # Process and print the reviews
                
                rev = ""
                for review in reviews[:3]:
                    review_text = review['text']
                    rating = review['rating']
                    reviewer_name = review['user']['name']

                    rev = rev + review_text + ". "   
                    
             
                res.append({
                    "name" : name, "rating": rating, "address": address, "description": description, "review": rev,
                    "distrito":distrito,
                    "alias":alias,
                    "name":nombre,
                    "image_url":image_url,
                    "is_closed":is_closed,
                    "review_count":review_count,
                    "latitude":latitude,
                    "longitude": longitude,
                    "location":location,
                    "display_phone":display_phone,
                    "price":price,
                    "hours":hours,
                    "transactions":transactions,
                    "languages":languages,
                    "attributes":attributes,
                    "transit":transit,
                    "best_time":best_time,
                    "delivery":delivery,
                    "pickup":pickup,
                    "online_ordering":online_ordering
                })
        except json.JSONDecodeError:
            print("La respuesta no es un JSON válido")

dfDistritoX = pd.DataFrame(res)
dfDistritoX
print(f"Name: {name}, \nRating: {rating}, \nAddress: {address}, \nDescription: {description}")
# Out:
# Retiro 20
# ---------------------------------------------------------------------------
# YelpAPIError                              Traceback (most recent call last)
# Cell In[102], line 137
#     136 # Make the API call to retrieve reviews for the current business
# --> 137 reviews_response = yelp_api.reviews_query(id=restaurant["id"],location="Madrid", lang="es")
#     139 # Extract the reviews from the response
#
# File c:\Python39\lib\site-packages\yelpapi\yelpapi.py:234, in YelpAPI.reviews_query(self, id, **kwargs)
#     232     raise ValueError('A valid business ID (parameter "id") must be provided.')
# --> 234 return self._query(REVIEWS_API_URL.format(id), **kwargs)
#
# File c:\Python39\lib\site-packages\yelpapi\yelpapi.py:299, in YelpAPI._query(self, url, **kwargs)
#     298 if 'error' in response_json:
# --> 299     raise YelpAPI.YelpAPIError('{}: {}'.format(response_json['error']['code'],
#     300                                                response_json['error']['description']))
#     302 # we got a good response, so return
#
# YelpAPIError: ACCESS_LIMIT_REACHED: You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 176
#     150             rev = rev + review_text + ". "
#     153         res.append({
#     154             "name" : name, "rating": rating, "address": address, "description": description, "review": rev,
#     155             "distrito":distrito,
#    (...)
#     174             "online_ordering":online_ordering
#     175         })
# --> 176 except json.JSONDecodeError:
#     177     print("La respuesta no es un JSON válido")
#
# NameError: name 'json' is not defined

# %%
dfDistrito1 = pd.DataFrame(res)

# %%
dfDistrito1.shape
# Out:
# (20, 24)

# %%
dfDistrito1.to_csv("../data/distritos1.csv")

# %%
df = dfDistrito1
df.shape
# Out:
# (60, 24)

# %%
import utm
import folium
from folium import plugins 
import ipywidgets
import geocoder
import geopy

# %%
map_madrid = folium.Map(location=[40.427919,-3.680877], zoom_start=14)

for (index, row) in df.iterrows():
    folium.Marker(location = [row.loc["latitude"], row.loc["longitude"]],
    popup = "<b>"+row.loc["description"] +"</b>" + " " + row["distrito"],
    tooltip = "ver").add_to(map_madrid)

map_madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c1373fc1e992c1663586ab022170136 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c1373fc1e992c1663586ab022170136&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c1373fc1e992c1663586ab022170136 = L.map(
#                 &quot;map_2c1373fc1e992c1663586ab022170136&quot;,
#                 {
#                     center: [40.427919, -3.680877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e36ded0af829f3fbe0a6199487758a3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c1373fc1e992c1663586ab022170136);
#
#
#             var marker_64a71d6364fc56ea16437b0f8257db10 = L.marker(
#                 [40.41508, -3.70192],
#                 {}
#             ).addTo(map_2c1373fc1e992c1663586ab022170136);
#
#
#         var popup_9811a06fdff68ae33dd9bee384a4a1ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71b318aeaf03dfe32b8aa93f1a1f78c1 = $(`&lt;div id=&quot;html_71b318aeaf03dfe32b8aa93f1a1f78c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tapas Bars Mediterranean &lt;/b&gt; Retiro&lt;/div&gt;`)[0];
#                 popup_9811a06fdff68ae33dd9bee384a4a1ec.setContent(html_71b318aeaf03dfe32b8aa93f1a1f78c1);
#
#
#
#         marker_64a71d6364fc56ea16437b0f8257db10.bindPopup(popup_9811a06fdff68ae33dd9bee384a4a1ec)
#         ;
#
#
#
#
#             marker_64a71d6364fc56ea16437b0f8257db10.bindTooltip(
#                 `&lt;div&gt;
#                      ver
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e9b9726eaaa9b74267f42f4df8158bc7 = L.marker(
#                 [40.4158141746249, -3.70297881289753],
#                 {}
#             ).addTo(map_2c1373fc1e992c1663586ab022170136);
#
#
#         var popup_0aa997ec5a9b73e01dbadc1fd7422445 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9174cea588304c5cbe23c045ab323efe = $(`&lt;div id=&quot;html_9174cea588304c5cbe23c045ab323efe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tapas Bars Spanish &lt;/b&gt; Retiro&lt;/div&gt;`)[0];
#                 popup_0aa997ec5a9b73e01dbadc1fd7422445.setContent(html_9174cea588304c5cbe23c045ab323efe);
#
#
#
#         marker_e9b9726eaaa9b74267f42f4df8158bc7.bindPopup(popup_0aa997ec5a9b73e01dbadc1fd7422445)
#         ;
#
#
#
#
#             marker_e9b9726eaaa9b74267f42f4df8158bc7.bindTooltip(
#                 `&lt;div&gt;
#                      ver
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_76d6d077d015580d9ddce1743d6e460f = L.marker(
#                 [40.4109993, -3.6943901],
#                 {}
#             ).addTo(map_2c1373fc1e992c1663586ab022170136);
#
#
#         var popup_3fbfd92818ff97558b3166b0aa35194b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c323cb62babdb25c0a1cf52c6f22302 = $(`&lt;div id=&quot;html_4c323cb62babdb25c0a1cf52c6f22302&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tapas Bars Wine Bars Tabernas &lt;/b&gt; Retiro&lt;/div&gt;`)[0];
#                 popup_3fbfd92818ff97558b3166b0aa35194b.setContent(html_4c323cb62babdb25c0a1cf52c6f22302);
#
#
#
#         marker_76d6d077d015580d9ddce1743d6e460f.bindPopup(popup_3fbfd92818ff97558b3166b0aa35194b)
#         ;
#
#
#
#
#             marker_76d6d077d015580d9ddce1743d6e460f.bindTooltip(
#                 `&lt;div&gt;
#                      ver
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3aabf91f3c383ec6ad3eb0c653fd644f = L.marker(
#                 [40.4154635, -3.6995421],
#                 {}
#             ).addTo(map_2c1373fc1e992c1663586ab022170136);
#
#
#         var popup_b346dcb88bb9e5ddc4a397c3d75ecc94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fcd89208820a4b76439046861febda1c = $(`&lt;div id=&quot;html_fcd89208820a4b76439046861febda1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Spanish Tablao Flamenco &lt;/b&gt; Retiro&lt;/div&gt;`)[0];
#                 popup_b346dcb88bb9e5ddc4a397c3d75ecc94.setContent(html_fcd89208820a4b76439046861febda1c);
#
#
#
#         marker_3aabf91f3c383ec6ad3eb0c653fd644f.bindPopup(popup_b346dcb88bb9e5ddc4a397c3d75ecc94)
#         ;
#
#
#
#
#             marker_3aabf91f3c383ec6ad3eb0c653fd644f.bindTooltip(

# %%
dfDistritoX.to_csv("../data/distrito1.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 dfDistritoX.to_csv("../data/distrito1.csv")
#
# NameError: name 'dfDistritoX' is not defined
