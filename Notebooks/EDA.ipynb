# %% [markdown]
# ### <div align="center">***LIMPIEZA Y ANALISIS DE DATOS***</div>
# ***
# Concatenamos los csv con los datos extraídos de los comercios de los 21 distritos de Madrid.

# %% [markdown]
# #### **IMPORTS**

# %%
import pandas as pd
from utils.utils import LoadSetCSV
import folium

# %% [markdown]
# ##### **CONCATENACION DE LOS CSV EN UN UNICO DF**

# %%
## LECTURA Y CONCATENACION DE CSV

lista_distritos = [
('../data/arganzuela.csv', 'Arganzuela'),              # Arganzuela 
('../data/barajas.csv', 'Barajas'),                    # Barajas  
('../data/carabanchel.csv', 'Carabanchel'),            # Carabanchel  
('../data/centro.csv', 'Centro'),                      # Centro   
('../data/chamartin.csv', 'Chamartin'),                # Chamartin 
('../data/chamberi.csv', 'Chamberi'),                  # Chamberi 
('../data/ciudadlineal.csv', 'Ciudad_Lineal'),         # Ciudad Lineal 
('../data/fuencarral.csv', 'Fuencarral-El_Pardo'),     # Fuencarral - El Pardo 
('../data/hortaleza.csv', 'Hortaleza'),                # Hortaleza  
('../data/latina.csv', 'Latina'),                      # Latina  
('../data/moncloa.csv', 'Moncloa-Aravaca'),            # Moncloa - Aravaca 
('../data/moratalaz.csv', 'Moratalaz'),                # Moratalaz  
('../data/retiro.csv', 'Retiro'),                      # Retiro   
('../data/salamanca.csv', 'Salamanca'),                # Salamanca 
('../data/sanblas.csv', 'San_Blas-Canillejas'),        # San Blas - Canillejas 
('../data/tetuan.csv', 'Tetuan'),                      # Tetuan 
('../data/usera.csv', 'Usera'),                        # Usera  
('../data/puentevallecas.csv', 'Puente_de_Vallecas'),  # Puente de Vallecas  
('../data/vicalvaro.csv', 'Vicalvaro'),                # Vicalvaro  
('../data/villaverde.csv', 'Villaverde'),              # Villaverde 
('../data/villavallecas.csv', 'Villa_de_Vallecas'),    # Villaverde de vallecas  
]

df_comercios = LoadSetCSV(lista_distritos)

# %%
df_comercios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1039 entries, 0 to 49
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1039 non-null   int64
#  1   id               1039 non-null   object
#  2   name             1039 non-null   object
#  3   alias            1039 non-null   object
#  4   categories       1039 non-null   object
#  5   description      1039 non-null   object
#  6   latitude         1039 non-null   float64
#  7   longitude        1039 non-null   float64
#  8   address          1039 non-null   object
#  9   phone            995 non-null    float64
#  10  rating           1039 non-null   float64
#  11  review_count     1039 non-null   int64
#  12  review           667 non-null    object
#  13  url              1039 non-null   object
#  14  image_url        996 non-null    object
#  15  is_closed        1039 non-null   bool
#  16  price            822 non-null    object
#  17  hours            0 non-null      float64
#  18  transactions     1039 non-null   object
#  19  languages        0 non-null      float64
#  20  attributes       0 non-null      float64
#  21  transit          0 non-null      float64
#  22  best_time        0 non-null      float64
#  23  delivery         0 non-null      float64
#  24  pickup           0 non-null      float64
#  25  online_ordering  0 non-null      float64
#  26  origin           1039 non-null   object
# dtypes: bool(1), float64(12), int64(2), object(12)
# memory usage: 220.2+ KB

# %% [markdown]
# #### **LIMPIEZA Y EDA**
#
# Tenemos un dataframe compuesto por:
# - 712 registros, equivalente al numero de comercios registrados en Madrid como punto de reciclado de aceite.
# - 14 columnas: id, name, alias, descripcion, latitude, longitude, address, phone, rating, review_count, reviez, url, image_url, price.
# - Hay valores nulos en las columnas 'review','image_url', 'phone' y 'price'.
# - Había 327 registros duplicados que eliminamos mediante el id único.

# %%
## ELIMINAMOS COLUMNAS INUTILES

df_comercios.drop(['Unnamed: 0','hours','transactions','languages','attributes','transit','best_time','delivery','pickup','online_ordering','categories', 'is_closed'], axis=1, inplace= True)

# %%
## COMPROBAMOS DUPLICADOS. 

print(df_comercios['id'].duplicated().any()) # Hay comercios duplicados. Filtramos por id que es único.
df_comercios[df_comercios['id'].duplicated()]
# Out:
# True
#                         id               name                     alias  \
# 0   m-suxON2HwsWYImvTNX1Jw              Botín            botín-madrid-3
# 1   S-Md-BF6C53iB2OlB5BCww         Casa Lucas         casa-lucas-madrid
# 2   afcRqfWrcA1soyoNI__FRQ      Juana la Loca    juana-la-loca-madrid-2
# 3   uHL7ravKYyrTl07fv_hfUg       Rosi La Loca       rosi-la-loca-madrid
# 4   iNtK9yWv7wOXaPai3uAv-g      InClan Brutal      inclan-brutal-madrid
# ..                     ...                ...                       ...
# 27  jgBTxwO0CDJQnxT5IpNcbw   Sienna Vicalvaro   sienna-vicalvaro-madrid
# 28  Clsa6wDBgxsgowTGueMLnQ            Kapicúa          kapicúa-madrid-2
# 31  eBgwj5HxASNHuIj7aQntLA  La Birra es Bella  la-birra-es-bella-madrid
# 37  lozi5r68Dhp0tGEP2z5ltw       Reina Banana       reina-banana-madrid
# 39  DQn7Gt5fpCPnvkTFTEVppQ             La Era           la-era-madrid-2
#
#                              description   latitude  longitude  \
# 0                   Spanish Steakhouses   40.414060  -3.708030
# 1                  Tapas Bars Wine Bars   40.412325  -3.709429
# 2            Tapas/Small Plates Spanish   40.411358  -3.711094
# 3                    Tapas Bars Spanish   40.415814  -3.702979
# 4              Tapas Bars Mediterranean   40.415080  -3.701920
# ..                                   ...        ...        ...
# 27  Ice Cream & Frozen Yogurt Cafeteria   40.402510  -3.606250
# 28                           Tapas Bars   40.382820  -3.607890
# 31                              Spanish   40.396825  -3.621028
# 37                                Vegan   40.402233  -3.608465
# 39           Tapas/Small Plates Spanish   40.395773  -3.623700
#
#                                               address         phone  rating  \
# 0       Calle de Cuchilleros, 17, 28005 Madrid, Spain  3.491366e+10     3.0
# 1      Calle de la Cava Baja, 30, 28005 Madrid, Spain  3.491365e+10     5.0
# 2    Plaza de Puerta de Moros, 4, 28005 Madrid, Spain  3.491364e+10     5.0
# 3              Calle de Cádiz, 4, 28012 Madrid, Spain  3.491533e+10     4.0
# 4          Calle Álvarez Gato, 4, 28012 Madrid, Spain  3.491024e+10     5.0
# ..                                                ...           ...     ...
# 27              Calle Galeote, 1, 28032 Madrid, Spain  3.465689e+10     4.5
# 28       Calle de Puentelarra, 7, 28031 Madrid, Spain           NaN     5.0
# 31      Bulevar de José Prat, 32, 28032 Madrid, Spain  3.467877e+10     4.0
# 37   Calle del Lago Titicaca, 10, 28032 Madrid, Spain  3.491255e+10     5.0
# 39  Bulevar de Indalecio Prieto, 46, 28032 Madrid,...  3.491371e+10     5.0
#
#     review_count                                             review  \
# 0            648  Historical restaurant that we felt honored to ...
# 1            157  Great little tapas wine bar on Calle cava baja...
# 2            220  This is my first meal in Spain, that is easily...
# 3            194  Rosie La Loca is the result of someone saying ...
# 4            171  Amazing cocktails and good service!!!!! Also l...
# ..           ...                                                ...
# 27             4                                                NaN
# 28             1                                                NaN
# 31             1                                                NaN
# 37             1                                                NaN
# 39             1                                                NaN
#
#                                                   url  \
# 0   https://www.yelp.com/biz/bot%C3%ADn-madrid-3?a...
# 1   https://www.yelp.com/biz/casa-lucas-madrid?adj...
# 2   https://www.yelp.com/biz/juana-la-loca-madrid-...
# 3   https://www.yelp.com/biz/rosi-la-loca-madrid?a...
# 4   https://www.yelp.com/biz/inclan-brutal-madrid?...
# ..                                                ...
# 27  https://www.yelp.com/biz/sienna-vicalvaro-madr...
# 28  https://www.yelp.com/biz/kapic%C3%BAa-madrid-2...
# 31  https://www.yelp.com/biz/la-birra-es-bella-mad...
# 37  https://www.yelp.com/biz/reina-banana-madrid?a...
# 39  https://www.yelp.com/biz/la-era-madrid-2?adjus...
#
#                                             image_url price             origin
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/UpGNFa...   €€€             Centro
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/xqe6Mv...    €€             Centro
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/NgunxE...   €€€             Centro
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/SN6sHZ...   €€€             Centro
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/qnACZF...    €€             Centro
# ..                                                ...   ...                ...
# 27  https://s3-media4.fl.yelpcdn.com/bphoto/KpU7n1...   €€€  Villa_de_Vallecas
# 28  https://s3-media3.fl.yelpcdn.com/bphoto/FiUidY...   NaN  Villa_de_Vallecas
# 31  https://s3-media2.fl.yelpcdn.com/bphoto/Ba4GI4...   NaN  Villa_de_Vallecas
# 37  https://s3-media3.fl.yelpcdn.com/bphoto/Z2Pa8Z...    €€  Villa_de_Vallecas
# 39  https://s3-media2.fl.yelpcdn.com/bphoto/3Gy39G...     €  Villa_de_Vallecas
#
# [327 rows x 15 columns]

# %%
## ELIMINAMOS DUPLICADOS

df_comercios = df_comercios.drop_duplicates(subset='id', keep='first') # keep='first' mantiene la primera aparición de cada valor único y elimina las duplicaciones posteriores.

# %%
df_comercios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            712 non-null    object
#  1   name          712 non-null    object
#  2   alias         712 non-null    object
#  3   description   712 non-null    object
#  4   latitude      712 non-null    float64
#  5   longitude     712 non-null    float64
#  6   address       712 non-null    object
#  7   phone         672 non-null    float64
#  8   rating        712 non-null    float64
#  9   review_count  712 non-null    int64
#  10  review        412 non-null    object
#  11  url           712 non-null    object
#  12  image_url     674 non-null    object
#  13  price         527 non-null    object
#  14  origin        712 non-null    object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 89.0+ KB

# %%
df_comercios.head(3)
# Out:
#                        id           name                   alias  \
# 0  iNtK9yWv7wOXaPai3uAv-g  InClan Brutal    inclan-brutal-madrid
# 1  afcRqfWrcA1soyoNI__FRQ  Juana la Loca  juana-la-loca-madrid-2
# 2  uHL7ravKYyrTl07fv_hfUg   Rosi La Loca     rosi-la-loca-madrid
#
#                    description   latitude  longitude  \
# 0    Tapas Bars Mediterranean   40.415080  -3.701920
# 1  Tapas/Small Plates Spanish   40.411358  -3.711094
# 2          Tapas Bars Spanish   40.415814  -3.702979
#
#                                             address         phone  rating  \
# 0        Calle Álvarez Gato, 4, 28012 Madrid, Spain  3.491024e+10     5.0
# 1  Plaza de Puerta de Moros, 4, 28005 Madrid, Spain  3.491364e+10     5.0
# 2            Calle de Cádiz, 4, 28012 Madrid, Spain  3.491533e+10     4.0
#
#    review_count                                             review  \
# 0           171  Amazing cocktails and good service!!!!! Also l...
# 1           220  This is my first meal in Spain, that is easily...
# 2           194  Rosie La Loca is the result of someone saying ...
#
#                                                  url  \
# 0  https://www.yelp.com/biz/inclan-brutal-madrid?...
# 1  https://www.yelp.com/biz/juana-la-loca-madrid-...
# 2  https://www.yelp.com/biz/rosi-la-loca-madrid?a...
#
#                                            image_url price      origin
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/qnACZF...    €€  Arganzuela
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/NgunxE...   €€€  Arganzuela
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/SN6sHZ...   €€€  Arganzuela

# %%
map_madrid = folium.Map(location=[40.427919,-3.680877], zoom_start=14)

for (index, row) in df_comercios.iterrows():
    folium.Marker(location = [row.loc["latitude"], row.loc["longitude"]],
    #popup = row.loc["rotulo"] + " " + row["desc_distrito_local"],
    tooltip = "click").add_to(map_madrid)

map_madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d304dc1bb2861a96941a5fd20a7f6b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d304dc1bb2861a96941a5fd20a7f6b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d304dc1bb2861a96941a5fd20a7f6b0 = L.map(
#                 &quot;map_5d304dc1bb2861a96941a5fd20a7f6b0&quot;,
#                 {
#                     center: [40.427919, -3.680877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5fa11dd4fcb7e1f588f44f6170c5249 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             var marker_deb1ecdea3f897147b218a5d9664baa7 = L.marker(
#                 [40.41508, -3.70192],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_deb1ecdea3f897147b218a5d9664baa7.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4a0a5a6a854ad9d5033eb25c00442f0b = L.marker(
#                 [40.4113584, -3.711094],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_4a0a5a6a854ad9d5033eb25c00442f0b.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_723db2e4eff01083e82ed0cc0ac1af0c = L.marker(
#                 [40.4158141746249, -3.70297881289753],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_723db2e4eff01083e82ed0cc0ac1af0c.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_351a7ae0e2e12c15262c5ed37b35a903 = L.marker(
#                 [40.4109993, -3.6943901],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_351a7ae0e2e12c15262c5ed37b35a903.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c4f4e586e574224cfafbadc8125f5830 = L.marker(
#                 [40.412325, -3.709429],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_c4f4e586e574224cfafbadc8125f5830.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_25f9dc2a1f7c863f15673bb2b4279d54 = L.marker(
#                 [40.4204554916193, -3.71240258216858],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_25f9dc2a1f7c863f15673bb2b4279d54.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9f1bf27307591769d82cd2dd42ec54fc = L.marker(
#                 [40.41287, -3.69724],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_9f1bf27307591769d82cd2dd42ec54fc.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_456ef4dbd2970a40b99fe8a4b7020741 = L.marker(
#                 [40.420185, -3.6974769],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_456ef4dbd2970a40b99fe8a4b7020741.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3cd2020854f260684f6134aefc4aea71 = L.marker(
#                 [40.41406, -3.70803],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_3cd2020854f260684f6134aefc4aea71.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ea18b66ba369b3c5fcff2d36938bd39c = L.marker(
#                 [40.4124, -3.69703],
#                 {}
#             ).addTo(map_5d304dc1bb2861a96941a5fd20a7f6b0);
#
#
#             marker_ea18b66ba369b3c

# %% [markdown]
# #### **CONVESION A CSV PARA BBDD**

# %%
df_comercios.to_csv('../data/df_comerios.csv', index =False) # No se incluye el índice del DataFrame en el archivo CSV.
