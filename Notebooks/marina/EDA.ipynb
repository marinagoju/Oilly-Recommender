# %% [markdown]
# ### <div align="center">***LIMPIEZA Y ANALISIS DE DATOS***</div>
# ***
# Concatenamos los csv con los datos extraídos de los comercios de los 21 distritos de Madrid.

# %% [markdown]
# #### **IMPORTS**

# %%
import pandas as pd
from utils import LoadSetCSV
import folium

# %% [markdown]
# ##### **CONCATENACION DE LOS CSV EN UN UNICO DF**

# %%
## LECTURA Y CONCATENACION DE CSV

lista_distritos = [
('../data/arganzuela.csv', 'Arganzuela'),              # Arganzuela 
('../data/barajas.csv', 'Barajas'),                    # Barajas  
('../data/carabanchel.csv', 'Carabanchel'),            # Carabanchel  
('../data/centro.csv', 'Centro'),                      # Centro   
('../data/chamartin.csv', 'Chamartin'),                # Chamartin 
('../data/chamberi.csv', 'Chamberi'),                  # Chamberi 
('../data/ciudadlineal.csv', 'Ciudad_Lineal'),         # Ciudad Lineal 
('../data/fuencarral.csv', 'Fuencarral-El_Pardo'),     # Fuencarral - El Pardo 
('../data/hortaleza.csv', 'Hortaleza'),                # Hortaleza  
('../data/latina.csv', 'Latina'),                      # Latina  
('../data/moncloa.csv', 'Moncloa-Aravaca'),            # Moncloa - Aravaca 
('../data/moratalaz.csv', 'Moratalaz'),                # Moratalaz  
('../data/retiro.csv', 'Retiro'),                      # Retiro   
('../data/salamanca.csv', 'Salamanca'),                # Salamanca 
('../data/sanblas.csv', 'San_Blas-Canillejas'),        # San Blas - Canillejas 
('../data/tetuan.csv', 'Tetuan'),                      # Tetuan 
('../data/usera.csv', 'Usera'),                        # Usera  
('../data/puentevallecas.csv', 'Puente_de_Vallecas'),  # Puente de Vallecas  
('../data/vicalvaro.csv', 'Vicalvaro'),                # Vicalvaro  
('../data/villaverde.csv', 'Villaverde'),              # Villaverde 
('../data/villavallecas.csv', 'Villa_de_Vallecas'),    # Villaverde de vallecas
('../data/zonabridge.csv', 'Salamanca'),    
('../data/zonabridge.csv', 'Tetuan'),    
]

df_comercios = LoadSetCSV(lista_distritos)

# %%
df_comercios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1109 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1109 non-null   int64
#  1   id               1109 non-null   object
#  2   name             1109 non-null   object
#  3   rating           1109 non-null   float64
#  4   address          1109 non-null   object
#  5   description      1107 non-null   object
#  6   review           571 non-null    object
#  7   alias            1109 non-null   object
#  8   image_url        1026 non-null   object
#  9   is_closed        1109 non-null   bool
#  10  review_count     1109 non-null   int64
#  11  latitude         1109 non-null   float64
#  12  longitude        1109 non-null   float64
#  13  location         1109 non-null   object
#  14  display_phone    1008 non-null   object
#  15  price            741 non-null    object
#  16  hours            0 non-null      float64
#  17  transactions     1109 non-null   object
#  18  languages        0 non-null      float64
#  19  attributes       0 non-null      float64
#  20  transit          0 non-null      float64
#  21  best_time        0 non-null      float64
#  22  delivery         0 non-null      float64
#  23  pickup           0 non-null      float64
#  24  online_ordering  0 non-null      float64
#  25  distrito         1109 non-null   object
# dtypes: bool(1), float64(11), int64(2), object(12)
# memory usage: 226.3+ KB

# %% [markdown]
# #### **LIMPIEZA Y EDA**
#
# Tenemos un dataframe compuesto por:
# - 958 registros, equivalente al numero de comercios registrados en Madrid como punto de reciclado de aceite.
# - 15 columnas
# - Hay valores nulos en las columnas 'descripcion','review','image_url', display_phone y 'price'.
# - Había 151 registros duplicados que eliminamos mediante el id único.

# %%
## ELIMINAMOS COLUMNAS INUTILES

df_comercios.drop(['Unnamed: 0','hours','transactions','languages','attributes','transit','best_time','delivery','pickup','online_ordering'], axis=1, inplace= True)

# %%
## COMPROBAMOS DUPLICADOS. 

print(df_comercios['id'].duplicated().any()) # Hay comercios duplicados. Filtramos por id que es único.
df_comercios[df_comercios['id'].duplicated()]
# Out:
# True
#                         id                   name  rating  \
# 10  LQJpl8JLrR_o9cSWFFQjJg                   Samm     4.0
# 17  slUDLwXdDlI9lsQB3uvJvA                El Bund     4.0
# 24  6RNwcBqPaaOmqfnWyUfEbQ              La Vegana     2.0
# 49  WYVp0BVfms1ZOG39KYU9Rg                 Beytna     5.0
# 0   Fv9orpCINPsnXSvoEKYc-w                Alegría     3.5
# ..                     ...                    ...     ...
# 45  V05g1M-QgokTD3eEAjBkcw            Tartan Roof     5.0
# 46  ve8ThB2NbLWp_lEKzqQ_3w            Pomme Sucre     4.0
# 47  i_0Icrf_U4tRuyC2zDki_A                Faborit     5.0
# 48  Besw6h3Sump1qNCKqw4Qog     Tierra del Queiles     3.0
# 49  laZCuDjNQqe7AVWUxaYcyA  Taberna La Carmencita     1.0
#
#                                               address  \
# 10    Calle de Carlos Caamaño, 3, 28016 Madrid, Spain
# 17  Calle de Arturo Baldasano, 22, 28043 Madrid, S...
# 24         Calle Moscatelar, 1-J, 28043 Madrid, Spain
# 49      Calle del Moscatelar, 18, 28043 Madrid, Spain
# 0          Calle de Illescas, 98, 28047 Madrid, Spain
# ..                                                ...
# 45  Azotea del Círculo de Bellas Artes, Calle de A...
# 46        Calle de Barquillo, 49, 28004 Madrid, Spain
# 47           Calle de Alcalá, 61, 28014 Madrid, Spain
# 48        Calle de Hermosilla, 7, 28001 Madrid, Spain
# 49      Calle de La Libertad, 16, 28004 Madrid, Spain
#
#                                   description  \
# 10     Arroceria / Paella Tapas/Small Plates
# 17                                   Dim Sum
# 24                              Bars Spanish
# 49                            Middle Eastern
# 0                                    Chinese
# ..                                        ...
# 45                   Modern European Lounges
# 46  Desserts Coffee & Tea Breakfast & Brunch
# 47        Salad Cafeteria Breakfast & Brunch
# 48                        Spanish Tapas Bars
# 49       Spanish Tabernas Breakfast & Brunch
#
#                                                review  \
# 10  We were in Madrid and touring with a private g...
# 17  My friend and I are Chinese tourists from Lond...
# 24  This place you will get quite good serivce, an...
# 49  Excellent food!\nExcellent ambience.\nVery cou...
# 0                                                 NaN
# ..                                                ...
# 45  This place was awesome. We came here on a Sund...
# 46  I'm not sure why this place doesn't have a 5 s...
# 47  Noticed this chain a few times walking around ...
# 48  Artichokes, risotto, and oxtail  will feed two...
# 49  We always come here for vermut and sit in the ...
#
#                              alias  \
# 10                     samm-madrid
# 17                  el-bund-madrid
# 24              la-vegana-madrid-2
# 49                   beytna-madrid
# 0                 alegría-madrid-2
# ..                             ...
# 45              tartan-roof-madrid
# 46              pomme-sucre-madrid
# 47               faborit-madrid-19
# 48       tierra-del-queiles-madrid
# 49  taberna-la-carmencita-madrid-2
#
#                                             image_url  is_closed  \
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/2EvyBq...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/lPDYdr...      False
# 24  https://s3-media4.fl.yelpcdn.com/bphoto/-HML_b...      False
# 49  https://s3-media2.fl.yelpcdn.com/bphoto/1_7Abx...      False
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/RWF8qy...      False
# ..                                                ...        ...
# 45  https://s3-media2.fl.yelpcdn.com/bphoto/E-YORr...      False
# 46  https://s3-media2.fl.yelpcdn.com/bphoto/drp8yy...      False
# 47  https://s3-media2.fl.yelpcdn.com/bphoto/iGKj6D...      False
# 48  https://s3-media1.fl.yelpcdn.com/bphoto/TaM1ij...      False
# 49  https://s3-media3.fl.yelpcdn.com/bphoto/JWfsAh...      False
#
#     review_count   latitude  longitude  \
# 10            14  40.464280  -3.670000
# 17            17  40.456730  -3.658570
# 24             5  40.457299  -3.651579
# 49             3  40.456980  -3.648320
# 0              2  40.389870  -3.752720
# ..           ...        ...        ...
# 45            30  40.418420  -3.696639
# 46            28  40.424260  -3.695570
# 47            10  40.419782  -3.691285
# 48            22  40.426610  -3.688280
# 49            33  40.421080  -3.697310
#
#                                              location     display_phone price  \
# 10  {'address1': 'Calle de Carlos Caamaño, 3', 'ad...  +34 913 45 30 74   €€€
# 17  {'address1': 'Calle de Arturo Baldasano, 22', ...  +34 911 15 18 13    €€
# 24  {'address1': 'Calle Moscatelar, 1-J', 'address...  +34 913 00 39 85     €
# 49  {'address1': 'Calle del Moscatelar, 18', 'addr...  +34 916 14 48 47   NaN
# 0   {'address1': 'Calle de Illescas, 98', 'address...  +34 917 18 19 27   NaN
# ..                                                ...               ...   ...
# 45  {'address1': 'Azotea del Círculo de Bellas Art...  +34 672 55 71 71    €€
# 46  {'address1': 'Calle de Barquillo, 49', 'addres...  +34 913 08 31 85    €€
# 47  {'address1': 'Calle de Alcalá, 61', 'address2'...  +34 916 49 26 74     €
# 48  {'address1': 'Calle de Hermosilla, 7', 'addres...  +34 914 35 34 70    €€
# 49  {'address1': 'Calle de La Libertad, 16', 'addr...  +34 915 31 09 11    €€
#
#      distrito
# 10  Hortaleza
# 17  Hortaleza
# 24  Hortaleza
# 49  Hortaleza
# 0      Latina
# ..        ...
# 45     Tetuan
# 46     Tetuan
# 47     Tetuan
# 48     Tetuan
# 49     Tetuan
#
# [151 rows x 16 columns]

# %%
## ELIMINAMOS DUPLICADOS

df_comercios = df_comercios.drop_duplicates(subset='id', keep='first') # keep='first' mantiene la primera aparición de cada valor único y elimina las duplicaciones posteriores.

# %%
df_comercios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 958 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             958 non-null    object
#  1   name           958 non-null    object
#  2   rating         958 non-null    float64
#  3   address        958 non-null    object
#  4   description    956 non-null    object
#  5   review         463 non-null    object
#  6   alias          958 non-null    object
#  7   image_url      879 non-null    object
#  8   is_closed      958 non-null    bool
#  9   review_count   958 non-null    int64
#  10  latitude       958 non-null    float64
#  11  longitude      958 non-null    float64
#  12  location       958 non-null    object
#  13  display_phone  865 non-null    object
#  14  price          620 non-null    object
#  15  distrito       958 non-null    object
# dtypes: bool(1), float64(3), int64(1), object(11)
# memory usage: 120.7+ KB

# %%
df_comercios
# Out:
#                         id                          name  rating  \
# 0   GV-WXC3F4MUzwjhAH_f_XA           El Rincón Asturiano     1.0
# 1   7zpK35tqV8uFtg9BGwfbRg  Donde da la Vuelta el Viento     5.0
# 2   cxypKAKs_zzJ8kvB_6G2Bw                      El Valle     4.0
# 3   J6Mq8jWYD9ntHd0u4OQr9A              La Pequeña Graná     4.0
# 4   om6h-4trsKlw9cOp53QXcg                 Hermanos Egea     4.0
# ..                     ...                           ...     ...
# 44  CoqMKp12tEbL8BBMYujYQw                  Gastromaquia     5.0
# 45  V05g1M-QgokTD3eEAjBkcw                   Tartan Roof     5.0
# 46  ve8ThB2NbLWp_lEKzqQ_3w                   Pomme Sucre     4.0
# 47  i_0Icrf_U4tRuyC2zDki_A                       Faborit     5.0
# 49  laZCuDjNQqe7AVWUxaYcyA         Taberna La Carmencita     1.0
#
#                                               address  \
# 0      Calle de las Delicias, 26, 28045 Madrid, Spain
# 1   Calle de Mesón de Paredes, 81, 28012 Madrid, S...
# 2   Calle de Sebastián Herrera, 6, 28012 Madrid, S...
# 3      Calle de Embajadores, 124, 28045 Madrid, Spain
# 4   Calle de la Batalla del Salado, 33, 28045 Madr...
# ..                                                ...
# 44               Calle Pelayo, 4, 28004 Madrid, Spain
# 45  Azotea del Círculo de Bellas Artes, Calle de A...
# 46        Calle de Barquillo, 49, 28004 Madrid, Spain
# 47           Calle de Alcalá, 61, 28014 Madrid, Spain
# 49      Calle de La Libertad, 16, 28004 Madrid, Spain
#
#                                   description  \
# 0                Spanish Asturian Tapas Bars
# 1         Tapas Bars Spanish Modern European
# 2                        Asturian Tapas Bars
# 3     Tapas Bars Tapas/Small Plates Beer Bar
# 4   Spanish Mediterranean Tapas/Small Plates
# ..                                        ...
# 44              Latin American Mediterranean
# 45                   Modern European Lounges
# 46  Desserts Coffee & Tea Breakfast & Brunch
# 47        Salad Cafeteria Breakfast & Brunch
# 49       Spanish Tabernas Breakfast & Brunch
#
#                                                review  \
# 0   We are here for dinner again on two consecutiv...
# 1   Great place with friendly staff. I came for ta...
# 2   The size of everything you order at this resta...
# 3   Delicious tapas with awesome service. We order...
# 4   The service was phenomenal, very understanding...
# ..                                                ...
# 44  Gastromaquia is aptly named. We had a gastrono...
# 45  This place was awesome. We came here on a Sund...
# 46  I'm not sure why this place doesn't have a 5 s...
# 47  Noticed this chain a few times walking around ...
# 49  We always come here for vermut and sit in the ...
#
#                                   alias  \
# 0          el-rincón-asturiano-madrid-2
# 1   donde-da-la-vuelta-el-viento-madrid
# 2                       el-valle-madrid
# 3             la-pequeña-graná-madrid-2
# 4                hermanos-egea-madrid-2
# ..                                  ...
# 44                gastromaquia-madrid-4
# 45                   tartan-roof-madrid
# 46                   pomme-sucre-madrid
# 47                    faborit-madrid-19
# 49       taberna-la-carmencita-madrid-2
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/cS74hs...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/4YsbpQ...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/RApDyk...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/BhD7tJ...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/rg5ZUM...      False
# ..                                                ...        ...
# 44  https://s3-media4.fl.yelpcdn.com/bphoto/U7S6u1...      False
# 45  https://s3-media2.fl.yelpcdn.com/bphoto/E-YORr...      False
# 46  https://s3-media2.fl.yelpcdn.com/bphoto/drp8yy...      False
# 47  https://s3-media2.fl.yelpcdn.com/bphoto/iGKj6D...      False
# 49  https://s3-media3.fl.yelpcdn.com/bphoto/JWfsAh...      False
#
#     review_count   latitude  longitude  \
# 0             32  40.403985  -3.692258
# 1             37  40.406190  -3.701441
# 2             21  40.403780  -3.699350
# 3             35  40.399390  -3.698510
# 4              3  40.400160  -3.696130
# ..           ...        ...        ...
# 44            20  40.421890  -3.699030
# 45            30  40.418420  -3.696639
# 46            28  40.424260  -3.695570
# 47            10  40.419782  -3.691285
# 49            33  40.421080  -3.697310
#
#                                              location     display_phone price  \
# 0   {'address1': 'Calle de las Delicias, 26', 'add...  +34 915 30 89 68    €€
# 1   {'address1': 'Calle de Mesón de Paredes, 81', ...  +34 910 17 72 40     €
# 2   {'address1': 'Calle de Sebastián Herrera, 6', ...  +34 914 67 70 07     €
# 3   {'address1': 'Calle de Embajadores, 124', 'add...  +34 914 74 26 30     €
# 4   {'address1': 'Calle de la Batalla del Salado, ...  +34 914 68 46 82    €€
# ..                                                ...               ...   ...
# 44  {'address1': 'Calle Pelayo, 4', 'address2': ''...  +34 915 22 64 13   NaN
# 45  {'address1': 'Azotea del Círculo de Bellas Art...  +34 672 55 71 71    €€
# 46  {'address1': 'Calle de Barquillo, 49', 'addres...  +34 913 08 31 85    €€
# 47  {'address1': 'Calle de Alcalá, 61', 'address2'...  +34 916 49 26 74     €
# 49  {'address1': 'Calle de La Libertad, 16', 'addr...  +34 915 31 09 11    €€
#
#       distrito
# 0   Arganzuela
# 1   Arganzuela
# 2   Arganzuela
# 3   Arganzuela
# 4   Arganzuela
# ..         ...
# 44   Salamanca
# 45   Salamanca
# 46   Salamanca
# 47   Salamanca
# 49   Salamanca
#
# [958 rows x 16 columns]

# %%
map_madrid = folium.Map(location=[40.427919,-3.680877], zoom_start=14)

for (index, row) in df_comercios.iterrows():
    folium.Marker(location = [row.loc["latitude"], row.loc["longitude"]],
    #popup = row.loc["rotulo"] + " " + row["desc_distrito_local"],
    tooltip = "click").add_to(map_madrid)

map_madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d81326e2e76009201a906500554d9c49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d81326e2e76009201a906500554d9c49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d81326e2e76009201a906500554d9c49 = L.map(
#                 &quot;map_d81326e2e76009201a906500554d9c49&quot;,
#                 {
#                     center: [40.427919, -3.680877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b9326d9819e75b454455950b92220e8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             var marker_90a2430e1c7385b0f435b0dd0f1dc4cf = L.marker(
#                 [40.4039846, -3.6922585],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_90a2430e1c7385b0f435b0dd0f1dc4cf.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_579aa468aa01e7677c0c9a9bdf501d0d = L.marker(
#                 [40.4061902, -3.7014406],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_579aa468aa01e7677c0c9a9bdf501d0d.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_acebfecaebcfe6e834104b0ee5861a8e = L.marker(
#                 [40.40378, -3.69935],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_acebfecaebcfe6e834104b0ee5861a8e.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f2c1a339a2919952cf6e48b4a4970e50 = L.marker(
#                 [40.3993899, -3.69851],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_f2c1a339a2919952cf6e48b4a4970e50.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6e73c752a2a2da51b446eaa678a780bb = L.marker(
#                 [40.40016, -3.69613],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_6e73c752a2a2da51b446eaa678a780bb.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bf4306e83704e1963c7cfa337f09b7b8 = L.marker(
#                 [40.4051, -3.69527],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_bf4306e83704e1963c7cfa337f09b7b8.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_10a1b23c5cf3dd62807f4b66e90824f2 = L.marker(
#                 [40.403755, -3.6909],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_10a1b23c5cf3dd62807f4b66e90824f2.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f7d97d3e9c2fbeddcd1ef0d8ef8f7a4e = L.marker(
#                 [40.4045817807007, -3.6966608723526],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_f7d97d3e9c2fbeddcd1ef0d8ef8f7a4e.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9bf26db021c909620a41de25eed38c31 = L.marker(
#                 [40.40173, -3.69881],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_9bf26db021c909620a41de25eed38c31.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d4c3ac02ea7a38e36816f32ae0957e31 = L.marker(
#                 [40.40614, -3.70307],
#                 {}
#             ).addTo(map_d81326e2e76009201a906500554d9c49);
#
#
#             marker_d4c3ac02ea7a38e36816f32ae0957e31.bi

# %% [markdown]
# #### **CONVESION A CSV PARA BBDD**

# %%
df_comercios.to_csv('../data/df_comerios.csv', index =False) # No se incluye el índice del DataFrame en el archivo CSV.
